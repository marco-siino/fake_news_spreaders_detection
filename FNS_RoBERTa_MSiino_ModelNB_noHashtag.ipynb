# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/fake_news_spreaders_detection/blob/main/FNS_RoBERTa_MSiino_ModelNB_noHashtag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Automated Detection of Fake News Spreaders: An Evaluative Study of Transformers and SOTA Models on Multilingual Dataset.
# RoBERTa Model, Training and Testing Notebook.
# Code by M. Siino.
#
# From the paper: "Automated Detection of Fake News Spreaders: An Evaluative Study of Transformers and SOTA Models on Multilingual Dataset." by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
# !pip install simpletransformers
# !pip install tensorboardx

import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf
import numpy as np
import torch
import pandas as pd

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from io import open
from pathlib import Path
from simpletransformers.classification import ClassificationModel, ClassificationArgs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simpletransformers in /usr/local/lib/python3.7/dist-packages (0.63.7)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.12.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (0.1.97)
# Requirement already satisfied: transformers>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (4.21.2)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (4.64.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.7.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2022.6.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.3.5)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (0.12.1)
# Requirement already satisfied: wandb>=0.10.32 in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (0.13.2)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2.23.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (0.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (4.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers>=4.6.0->simpletransformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers>=4.6.0->simpletransformers) (3.0.9)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (2.3)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (1.3.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (0.4.0)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (3.1.27)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (1.0.9)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (57.4.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (7.1.2)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (0.1.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (5.4.8)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (3.17.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb>=0.10.32->simpletransformers) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb>=0.10.32->simpletransformers) (5.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (1.25.11)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.3.5.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.18.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (3.8.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.70.13)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (2022.7.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (6.0.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (3.0.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=4.6.0->simpletransformers) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->simpletransformers) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->simpletransformers) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->simpletransformers) (1.1.0)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.2.4)
# Requirement already satisfied: validators>=0.2 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.20.0)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.2.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: semver in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (2.13.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.8.0b1)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (1.0.1)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (5.1.1)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (2.1.9)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (1.5.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (12.5.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (7.1.2)
# Requirement already satisfied: blinker>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (1.5)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (4.3.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.12.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (2.11.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers) (5.9.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers) (0.18.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->altair>=3.2.0->streamlit->simpletransformers) (2.0.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.6.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (0.9.1)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from validators>=0.2->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.37.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.2.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.47.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (3.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorboardx in /usr/local/lib/python3.7/dist-packages (2.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardx) (1.21.6)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardx) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardx) (1.15.0)

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
# Url obtained starting from this: https://drive.google.com/file/d/19ZcqEv88euKB71HfAWjTGN3uCKp2qsfP/ and forcing export=download.
urlTrainingSet = "https://github.com/marco-siino/fake_news_spreaders_detection/raw/main/dataset/pan20-author-profiling-training-2020-02-23.zip"
urlTestSet="https://github.com/marco-siino/fake_news_spreaders_detection/raw/main/dataset/pan20-author-profiling-test-2020-02-23.zip"

training_set = tf.keras.utils.get_file("pan20-author-profiling-training-2020-02-23.zip", urlTrainingSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')
test_set = tf.keras.utils.get_file("pan20-author-profiling-test-2020-02-23.zip", urlTestSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

training_set_dir = os.path.join(os.path.dirname(training_set), 'pan20-author-profiling-training-2020-02-23')
test_set_dir = os.path.join(os.path.dirname(test_set), 'pan20-author-profiling-test-2020-02-23')

print(training_set)
print(training_set_dir)

# !ls -A
# Out:
# ./pan20-author-profiling-training-2020-02-23.zip
# ./pan20-author-profiling-training-2020-02-23
# .config						runs
# __MACOSX					sample_data
# outputs						test_dir_en
# pan20-author-profiling-test-2020-02-23		test_dir_es
# pan20-author-profiling-test-2020-02-23.zip	train_dir_en
# pan20-author-profiling-training-2020-02-23	train_dir_es
# pan20-author-profiling-training-2020-02-23.zip

# %% [markdown]
# ## Build folders hierarchy to use Keras folders preprocessing function.

# %%
### Training Folders. ###

# First level directory.
if not os.path.exists('train_dir_en'):
    os.makedirs('train_dir_en')
if not os.path.exists('train_dir_es'):
    os.makedirs('train_dir_es')

# Class labels directory.
if not os.path.exists('train_dir_en/0'):
    os.makedirs('train_dir_en/0')
if not os.path.exists('train_dir_es/0'):
    os.makedirs('train_dir_es/0')
if not os.path.exists('train_dir_en/1'):
    os.makedirs('train_dir_en/1')
if not os.path.exists('train_dir_es/1'):
    os.makedirs('train_dir_es/1')

# Make Py variables.
train_dir='train_dir_'

## Test Folders. ##
# First level directory.
if not os.path.exists('test_dir_en'):
    os.makedirs('test_dir_en')
if not os.path.exists('test_dir_es'):
    os.makedirs('test_dir_es')

# Class labels directory.
if not os.path.exists('test_dir_en/0'):
    os.makedirs('test_dir_en/0')
if not os.path.exists('test_dir_es/0'):
    os.makedirs('test_dir_es/0')
if not os.path.exists('test_dir_en/1'):
    os.makedirs('test_dir_en/1')
if not os.path.exists('test_dir_es/1'):
    os.makedirs('test_dir_es/1')

# Make Py variables.
test_dir='test_dir_'

# !ls -A
# Out:
# .config						runs
# __MACOSX					sample_data
# outputs						test_dir_en
# pan20-author-profiling-test-2020-02-23		test_dir_es
# pan20-author-profiling-test-2020-02-23.zip	train_dir_en
# pan20-author-profiling-training-2020-02-23	train_dir_es
# pan20-author-profiling-training-2020-02-23.zip

# %% [markdown]
# ## Set language and directory paths.

# %%
# Set en and es train_dir and test_dir paths.
language='es'

truth_file_training_dir_es=training_set_dir+'/'+language+'/'
truth_file_training_path_es = truth_file_training_dir_es+'truth.txt'

truth_file_test_dir=test_set_dir
truth_file_test_path_es = truth_file_test_dir+'/'+language+'.txt'


language='en'

truth_file_training_dir_en=training_set_dir+'/'+language+'/'
truth_file_training_path_en = truth_file_training_dir_en+'truth.txt'

truth_file_test_path_en = truth_file_test_dir+'/'+language+'.txt'

# %% [markdown]
# ## Read truth.txt to organize training dataset folders.

# %%
# Organize EN folders.
language='en'
# Open the file truth.txt with read only permit.
f = open(truth_file_training_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_training_dir_en+fNameXml):
      os.rename(truth_file_training_dir_en+fNameXml, './train_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

language='es'
# Organize ES folders.
# Open the file truth.txt with read only permit.
f = open(truth_file_training_path_es, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_training_dir_es+fNameXml):
      os.rename(truth_file_training_dir_es+fNameXml, './train_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# %% [markdown]
# ## Read truth.txt to organize test dataset folders.

# %%
#Organize EN folders.
language='en'
# Open the file truth.txt with read only permit.
f = open(truth_file_test_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_dir+'/'+language+'/'+fNameXml, './test_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

#Organize EN folders.
language='es'
# Open the file truth.txt with read only permit.
f = open(truth_file_test_path_es, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_dir+'/'+language+'/'+fNameXml, './test_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# %% [markdown]
# ## Function to pre-process source text.

# %%
def custom_standardization(input_data):
  tag_open_CDATA_removed = tf.strings.regex_replace(input_data, '<\!\[CDATA\[', ' ')
  tag_closed_CDATA_removed = tf.strings.regex_replace(tag_open_CDATA_removed,'\]{1,}>', ' ')
  tag_author_lang_es_removed = tf.strings.regex_replace(tag_closed_CDATA_removed,'<author lang="es">', ' ')
  tag_author_lang_en_removed = tf.strings.regex_replace(tag_author_lang_es_removed,'<author lang="en">', ' ')
  tag_closed_author_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'</author>', ' ')
  tag_open_documents_removed = tf.strings.regex_replace(tag_closed_author_removed,'<documents>\n(\t){0,2}', '')
  output_data = tf.strings.regex_replace(tag_open_documents_removed,'</documents>\n(\t){0,2}', ' ')
  output_data_noHashtag = tf.strings.regex_replace(output_data,'#HASHTAG#', '')
  return output_data_noHashtag

# %% [markdown]
# ## Building the dataset.

# %%
batch_size=1

# Build the dataset for Spanish.
language='es'

raw_train_ds_es = tf.keras.preprocessing.text_dataset_from_directory(
    train_dir+language, 
    batch_size=batch_size, 
    #validation_split=0.0, 
    #subset='training', 
    shuffle='false',
    seed=1
    )

raw_test_ds_es = tf.keras.preprocessing.text_dataset_from_directory(
    test_dir+language, 
    batch_size=batch_size,
    shuffle='false'
    )


# Build the dataset for Spanish.
language='en'

raw_train_ds_en = tf.keras.preprocessing.text_dataset_from_directory(
    train_dir+language, 
    batch_size=batch_size, 
    #validation_split=0.0, 
    #subset='training', 
    shuffle='false',
    seed=1
    )

raw_test_ds_en = tf.keras.preprocessing.text_dataset_from_directory(
    test_dir+language, 
    batch_size=batch_size,
    shuffle='false'
    )
# Out:
# Found 300 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.
# Found 300 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.

# %% [markdown]
# ## Convert DSs to Pandas Dataframe

# %%
# Convert English dataset.
train_df_en = [] # will contain text and label
for element in raw_train_ds_en:
  authorDocument=element[0]
  label=int(element[1].numpy())
  #print(authorDocument[0])
  text = custom_standardization(authorDocument[0].numpy()).numpy().decode('UTF-8')
  train_df_en.append({
      'text':text,
      'label':label
  })
train_df_en = pd.DataFrame(train_df_en)
test_df_en = [] # will contain text and label
for element in raw_test_ds_en:
  authorDocument=element[0]
  label=int(element[1].numpy())
  #print(authorDocument[0])
  text = custom_standardization(authorDocument[0].numpy()).numpy().decode('UTF-8')
  test_df_en.append({
      'text':text,
      'label':label
  })
test_df_en = pd.DataFrame(test_df_en)

# Convert Spanish dataset.
train_df_es = [] # will contain text and label
for element in raw_train_ds_es:
  authorDocument=element[0]
  label=int(element[1].numpy())
  #print(authorDocument[0])
  text = custom_standardization(authorDocument[0].numpy()).numpy().decode('UTF-8')
  train_df_es.append({
      'text':text,
      'label':label
  })
train_df_es = pd.DataFrame(train_df_es)
test_df_es = [] # will contain text and label
for element in raw_test_ds_es:
  authorDocument=element[0]
  label=int(element[1].numpy())
  #print(authorDocument[0])
  text = custom_standardization(authorDocument[0].numpy()).numpy().decode('UTF-8')
  test_df_es.append({
      'text':text,
      'label':label
  })
test_df_es = pd.DataFrame(test_df_es)

# %% [markdown]
# ## Print some RAW and preprocessed samples (No need to execute)

# %%
for idx, element in enumerate(raw_train_ds_es):
  if idx>1: break
  authorDocument=element[0]
  label=element[1]
  temp = custom_standardization(authorDocument[0].numpy()).numpy().decode('UTF-8')
  print("Not-Preprocessed samples: \n",authorDocument)
  print("Preprocessed samples: \n",temp)
# Out:
# Not-Preprocessed samples:
#  tf.Tensor([b'<author lang="es">\n\t<documents>\n\t\t<document><![CDATA[DESCARGAR \xe2\x80\x93 Jacool el Fenomeno \xe2\x80\x93 Me la va dar (2015) #URL# Unete #USER# #URL#]]></document>\n\t\t<document><![CDATA[VIDEO \xe2\x80\x93 Mozart la Para \xe2\x80\x93 Llegan Lo Montro Men en Lucky 7, Newark! #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[Le Quitan La Vida A Un Dominicano En Un Parque Del Bronx #URL# #URL#]]></document>\n\t\t<document><![CDATA[Historia del Joven que durante el d\xc3\xada es un millonario y de noche vuelve a la\xe2\x80\xa6 #URL# Unete #USER# #URL#]]></document>\n\t\t<document><![CDATA[VIDEO \xe2\x80\x93 El publico le grita Martha heredia a vakero en pleno concierto y esta fue la respuesta. #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[VIDEO \xe2\x80\x93 Mozart La Para y Shelow Shaq Juntos en Concierto en Los Estados Unidos #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[VIDEO \xe2\x80\x93 Cineasta \xe2\x80\x9cEaten Alive\xe2\x80\x9d se deja comer vivo por una anaconda (VER PARA CREER) #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[VIDEO \xe2\x80\x93 El Alfa dando en preview de lo nuevo que viene #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[VIDEO \xe2\x80\x93 Le Gritan Lapiz Conciente a N-fasis en pleno concierto #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[VIDEO \xe2\x80\x93 Se Filtra video porno de Shakira cuando tenia 17 A\xc3\xb1os (2014) #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[VIDEO \xe2\x80\x93 Paramba Reta a Chimbala a apostar su Jeepeta quien pega mas canciones este 2015 #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[El Mayor Clasico Ft J\xe2\x80\x99Martin \xe2\x80\x93 Ni Una Lagrima (Video Oficial HD) #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[DE ULTIMO MINUTO \xe2\x80\x93 Arrestan a Carlos Montesquieu Por Correr Desnudo En La Serie Del Caribe #URL# #URL#]]></document>\n\t\t<document><![CDATA[Video \xe2\x80\x93 Momento en el cual Birdman le lanza un vaso de bebiba al famoso rapero Lil wayne su\xe2\x80\xa6 #URL# #URL#]]></document>\n\t\t<document><![CDATA[ESTRENO \xe2\x80\x93 El Alfa \xe2\x80\x93 Como Yo Me Muevo (Video Oficial) #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[VIDEO \xe2\x80\x93 Mozart la para en vivo Llegan los montrous concierto Yo Soy Urbano #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[ESTRENO MUNDIAL \xe2\x80\x93 Belen El Deconetao \xe2\x80\x93 Me quite un tenis (Video Oficial) #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[Fallece la actriz colombiana Adriana Campos en un accidente (FUERTES IMAGENES) #URL# #URL#]]></document>\n\t\t<document><![CDATA[VIDEO \xe2\x80\x93 C\xc3\xa1mara capta momentos en que pareja cae de tercer piso en Republica Dominicana #URL# #URL#]]></document>\n\t\t<document><![CDATA[DE ULTIMO MINUTO \xe2\x80\x93 El Chapo Guzm\xc3\xa1n Se Quita La Vida En Su Propia Celda (FUERTES IMAGENES) #URL# #URL#]]></document>\n\t\t<document><![CDATA[Furetes Imagenes De La Muerte del Pelotero Oscar Taveras #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[La Insuperable Se Destap\xc3\xb3 Y Empez\xc3\xb3 A Bailar Frente A Todos, Te Quedar\xc3\xa1s Boquiabierto #URL#]]></document>\n\t\t<document><![CDATA[Hijo Del Hombre Mas Rico Del Mundo Se Casa Rodeado De Oro #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[Apresan Hombre Dominicano Que Le Quit\xc3\xb3 La Vida A Su Expareja En Espa\xc3\xb1a #URL# Unete #USER# #URL#]]></document>\n\t\t<document><![CDATA[ESTRENO: Chombo Pana Black \xe2\x80\x93 Baja Lento (Video Oficial) #URL# Unete #USER# #URL#]]></document>\n\t\t<document><![CDATA[Mujer De 65 A\xc3\xb1os Queda Embarazada Nuevamente Y Esta Vez De Cuatrillizos #URL# Unete #USER# #URL#]]></document>\n\t\t<document><![CDATA[Fuertes Imagenes de 129 muertos en naufragio de una embarcaci\xc3\xb3n en El Congo #URL# Unete #USER#]]></document>\n\t\t<document><![CDATA[Gobierno anuncia rebaja de RD$12.85 en gasolina Premiun y RD$15.52 en  ...
# Preprocessed samples:
#
# 	<document> DESCARGAR – Jacool el Fenomeno – Me la va dar (2015) #URL# Unete #USER# #URL# </document>
# 		<document> VIDEO – Mozart la Para – Llegan Lo Montro Men en Lucky 7, Newark! #URL# Unete #USER# </document>
# 		<document> Le Quitan La Vida A Un Dominicano En Un Parque Del Bronx #URL# #URL# </document>
# 		<document> Historia del Joven que durante el día es un millonario y de noche vuelve a la… #URL# Unete #USER# #URL# </document>
# 		<document> VIDEO – El publico le grita Martha heredia a vakero en pleno concierto y esta fue la respuesta. #URL# Unete #USER# </document>
# 		<document> VIDEO – Mozart La Para y Shelow Shaq Juntos en Concierto en Los Estados Unidos #URL# Unete #USER# </document>
# 		<document> VIDEO – Cineasta “Eaten Alive” se deja comer vivo por una anaconda (VER PARA CREER) #URL# Unete #USER# </document>
# 		<document> VIDEO – El Alfa dando en preview de lo nuevo que viene #URL# Unete #USER# </document>
# 		<document> VIDEO – Le Gritan Lapiz Conciente a N-fasis en pleno concierto #URL# Unete #USER# </document>
# 		<document> VIDEO – Se Filtra video porno de Shakira cuando tenia 17 Años (2014) #URL# Unete #USER# </document>
# 		<document> VIDEO – Paramba Reta a Chimbala a apostar su Jeepeta quien pega mas canciones este 2015 #URL# Unete #USER# </document>
# 		<document> El Mayor Clasico Ft J’Martin – Ni Una Lagrima (Video Oficial HD) #URL# Unete #USER# </document>
# 		<document> DE ULTIMO MINUTO – Arrestan a Carlos Montesquieu Por Correr Desnudo En La Serie Del Caribe #URL# #URL# </document>
# 		<document> Video – Momento en el cual Birdman le lanza un vaso de bebiba al famoso rapero Lil wayne su… #URL# #URL# </document>
# 		<document> ESTRENO – El Alfa – Como Yo Me Muevo (Video Oficial) #URL# Unete #USER# </document>
# 		<document> VIDEO – Mozart la para en vivo Llegan los montrous concierto Yo Soy Urbano #URL# Unete #USER# </document>
# 		<document> ESTRENO MUNDIAL – Belen El Deconetao – Me quite un tenis (Video Oficial) #URL# Unete #USER# </document>
# 		<document> Fallece la actriz colombiana Adriana Campos en un accidente (FUERTES IMAGENES) #URL# #URL# </document>
# 		<document> VIDEO – Cámara capta momentos en que pareja cae de tercer piso en Republica Dominicana #URL# #URL# </document>
# 		<document> DE ULTIMO MINUTO – El Chapo Guzmán Se Quita La Vida En Su Propia Celda (FUERTES IMAGENES) #URL# #URL# </document>
# 		<document> Furetes Imagenes De La Muerte del Pelotero Oscar Taveras #URL# Unete #USER# </document>
# 		<document> La Insuperable Se Destapó Y Empezó A Bailar Frente A Todos, Te Quedarás Boquiabierto #URL# </document>
# 		<document> Hijo Del Hombre Mas Rico Del Mundo Se Casa Rodeado De Oro #URL# Unete #USER# </document>
# 		<document> Apresan Hombre Dominicano Que Le Quitó La Vida A Su Expareja En España #URL# Unete #USER# #URL# </document>
# 		<document> ESTRENO: Chombo Pana Black – Baja Lento (Video Oficial) #URL# Unete #USER# #URL# </document>
# 		<document> Mujer De 65 Años Queda Embarazada Nuevamente Y Esta Vez De Cuatrillizos #URL# Unete #USER# #URL# </document>
# 		<document> Fuertes Imagenes de 129 muertos en naufragio de una embarcación en El Congo #URL# Unete #USER# </document>
# 		<document> Gobierno anuncia rebaja de RD$12.85 en gasolina Premiun y RD$15.52 en Regular #URL# Unete #USER# </document>
# 		<document> Seis Policias Implicados en la Muerte del Joven Negro en Baltimore #URL# Unete #USER# #URL# </document>
# 		<document> VIDEO – Gran Presentacion de Jowell &amp; Randy @ Medellin, Colombia (2014) #URL# Unete #USER# </document>
# 		<document> VIDEO – Con tan solo 6 años de edad Artista Urbano rompe en televisión #URL# Unete #USER# </document>
# 		<document> Landy El Zapatero – Dime Mami (Official Video) #URL# Unete #USER# #URL# </document>
# 		<document> DESCARGAR – El Alfa – Como Yo Me Muevo (Dembow 2014) #URL# Unete #USER# </document>
# 		<document> Mangan a Don Miguelo Chuleandose con Una Fanatica (Foto) #URL# Unete #USER# </document>
# 		<document> María José Alvarado, Miss Honduras, es hallada muerta (FOTOS) #URL# Unete #USER# </document>
# 		<document> VIDEO – Joa ft Quimico &amp; Melymel – Los Jordan (En Vivo en TV) #URL# Unete #USER# </document>
# 		<document> DE ULTIMO MINUTO – Cae un Angel Del Cielo En Londres (Ver Para Creer) #URL# #URL# </document>
# 		<document> VIDEO – Mueren 116 Personas Al Estrellarse Avion Contra Un Hotel (Fuertes Imagenes) #URL# #URL# </document>
# 		<document> Historia del Joven que durante el día es un millonario y de noche vuelve a la… #URL# Unete #USER# #URL# </document>
# 		<document> ESTRENO – Jowell &amp; Randy Ft El Alfa &amp; Mas – Mi Cumpleaños (Video Oficial) #URL# Unete #USER# </document>
# 		<document> VIDEO – Arcangel Ft Cosculluela @ ArcaVSCoscu (En Vivo) (Cosliseo) #URL# Unete #USER# </document>
# 		<document> Muere en accidente Automovilístico Robinson Díaz (El Cabo) Actor Colombiano #URL# Unete #USER# </document>
# 		<document> Tito El Bambino – Controlando (Official Video) #URL# Unete #USER# </document>
# 		<document> VIDEO – Lapiz Conciente graba video Musical con Belinda y Juan Magan #URL# Unete #USER# </document>
# 		<document> Daddy Yankee Vuelve a la Escuela #URL# Unete #USER# #URL# </document>
# 		<document> VIDEO – El Estadio Cibao Se Prende en Fuego (Ver Para Creer) #URL# Unete #USER# </document>
# 		<document> VIDEO – El Alfa Se Roba El Show Bailando Con Bailarina del Mayor Clasico #URL# Unete #USER# #URL# </document>
# 		<document> VIDEO – Toxic Crow explica la experiencia de su primera luna de miel junto a su esposa #URL# Unete #USER# </document>
# 		<document> VIDEO – Don Miguelo Hace Historia en Miami (Concierto Completo) #URL# Unete #USER# #URL# </document>
# 		<document> 20 dominicanos en la lista de personas más buscadas por el FBI #URL# Unete #USER# </document>
# 		<document> Policía Nacional apresa con 24 libras de marihuana jefe Dican en Dajabón #URL# Unete #USER# </document>
# 		<document> VIDEO – Joven Lucha Por Su Vida, Por Buscar Mejorar su Apariencia #URL# Unete #USER# #URL# </document>
# 		<document> Niña De 11 Años Que Ha Dejado A Todos Sorprendidos Con Su Encantadora Voz #URL# Unete #USER# </document>
# 		<document> VIDEO – Toxic Crow explica la experiencia de su primera luna de miel junto a su esposa #URL# Unete #USER# </document>
# 		<document> Lapiz Conciente Ft Mandrake, Sin Freno Y El Pote – Atento Army (Descargar) #URL# Unete #USER# </document>
# 		<document> Fuerte Imagenes del Cuerpo Sin Vida del Pelotero Oscar Taveras #URL# Unete #USER# </document>
# 		<document> VIDEO – Lapiz Concienet y Vico C cantando Juntos en Hard Rock Cafe #URL# Unete #USER# </document>
# 		<document> VIDEO – Madonna Se Besa a Drake en Pleno Concierto #URL# Unete #USER# #URL# </document>
# 		<document> ESTRENO MUNDIAL – Pablo Piddy – Mi Cuaderno Para Ciegos (Video Oficial) #URL# Unete #USER# </document>
# 		<document> ESTRENO – Mozart La Para – Pa Ella (Official Video) #URL# #URL# </document>
# 		<document> ESTRENO – Sensato – No Me Niegues (Official Video) #URL# Unete #USER# #URL# </document>
# 		<document> Arcángel Presentará Sus 50 Sombras #URL# Unete #USER# </document>
# 		<document> VIDEO – Omega El Fuerte bailando como “Michael Jackson” #URL# Unete #USER# </document>
# 		<document> Hombre mata a su pareja y a sus dos hijas #URL# Unete #USER# #URL# </document>
# 		<document> Falo Regresa Con Nuevo Tema De Verano #URL# Unete #USER# #URL# </document>
# 		<document> Chimbala Ft Don Miguelo – Coge Tu Camino (Lyric Video) #URL# Unete #USER# #URL# </document>
# 		<document> El Mayor Clasico – Tiradera El Alfa (En Vivo en Center Mambo Latino – Madrid) #URL# Unete #USER# </document>
# 		<document> Conozcan La Antigua Ciudad Que Se Encuentra Intacta Bajo El Agua #URL# Unete #USER# </document>
# 		<document> DE ULTIMO MINUTO – Fallece El Presentador Don Francisco #URL# #URL# </document>
# 		<document> VIDEO – Don Miguelo gana como Artista Urbano del Año en Premios Soberano #URL# Unete #USER# #URL# </document>
# 		<document> VIDEO – El Alfa lo hizo de nuevo (Llegale) #URL# Unete #USER# </document>
# 		<document> Universitarias se desnudan a cambio de alcohol (Ver Para Creer) #URL# Unete #USER# #URL# </document>
# 		<document> DE ULTIMO MINUTO – Fallece El Actor de Novela Rafael Amaya (El Señor De Los Cielos) #URL# #URL# </document>
# 		<document> VIDEO – Crazy Design le da trompada a guayubin en TV por intentar besarlo #URL# Unete #USER# </document>
# 		<document> VIDEO IMPACTANTE – Momento en el Que Explota Una Casa En Santiago, Republica… #URL# Unete #USER# #URL# </document>
# 		<document> VIDEO – Presentador Confunde a Milka La Mas Dura con La Materialista en Vivo #URL# Unete #USER# </document>
# 		<document> Fuertes Imagenes De La Muerte del Pelotero Oscar Taveras #URL# Unete #USER# </document>
# 		<document> DE ULTIMO MINUTO – Arrestan Al Joven Dominicano que Saco a su Esposa a Desnuda en New York #URL# #URL# </document>
# 		<document> ESTRENO – Vakero – Casate Conmigo (Descargar) #URL# Unete #USER# </document>
# 		<document> COMO CASTIGO: El Alfa tendrá que limpiar la Plaza de la Bandera y entonar el… #URL# Unete #USER# #URL# </document>
# 		<document> VIDEO – Hombre Lucha Contra Un Tiburón Para Salvar Su Vida #URL# #URL# </document>
# 		<document> ESTRENO MUNDIAL – Jacool El Fenomeno – Puteria (Video Oficial) #URL# Unete #USER# </document>
# 		<document> Proponen se explote la marihuana como una materia prima #URL# Unete #USER# </document>
# 		<document> VIDEO – El Chuape llama Guaremate a “El Alfa” &amp; otros dembowseros #URL# Unete #USER# </document>
# 		<document> DESCARGAR – El Mayor Clasico – Rastrero (Tiraera Pa El Alfa) (Dembow 2014) #URL# Unete #USER# </document>
# 		<document> Juan Magan Ft Gente De Zona – He Llorado (Como Un Niño) (Official Video) #URL# Unete #USER# #URL# </document>
# 		<document> Se Suicida el Actor Sawyer Sweeten (Fuertes Imagenes) #URL# Unete #USER# #URL# </document>
# 		<document> VIDEO – Entrevista a Carlos Montesquieu (Lenguaje fuerte) #URL# Unete #USER# </document>
# 		<document> DE ULTIMO MINUTO – Fallece El Actor de Novela Rafael Amaya (El Señor De Los Cielos) #URL# #URL# </document>
# 		<document> VIDEO – Presentacion de Lapiz Conciente, Juan magan y Belinda en Los Latin Billboard #URL# Unete #USER# </document>
# 		<document> THE CARTIER DISCOTEC PRESENTA: Gran Reinaguracion: A Casa Llena Con Jacool El Fenomeno, El Londy &amp;… #URL# Unete #USER# </document>
# 		<document> VIDEO – Melymel Preparando una colaboracion con Anthony Santos #URL# Unete #USER# #URL# </document>
# 		<document> DE ULTIMO MINUTO – Encuentran micro chip en la batería de los galaxy que espían las… #URL# #URL# </document>
# 		<document> QUE BIEN: Pareja se encuentra a traves de facebook despues de 70 años y se casan #URL# Unete #USER# </document>
# 		<document> Fuertes Imagenes del Cuerpo Sin Vida de Miss Honduras 2014 #URL# Unete #USER# </document>
# 		<document> VIDEO – Vakero Besa a Su Novia la Bailarina en Pleno Concierto #URL# Unete #USER# </document>
# 		<document> COMO CASTIGO: El Alfa tendrá que limpiar la Plaza de la Bandera y entonar el… #URL# Unete #USER# #URL# </document>
# 		<document> ESTRENO – Omega El Fuerte – En La Avenida (Official Video) #URL# #URL# </document>
# 		<document> MUY FUERTE – Su hija moría, él no tenía dinero, así que arriesgo todo y esto fue lo que hizo #URL# #URL# </document>
# 		<document> Hallan 400 kilos de cocaína en casa de Paris Hilton #URL# Unete #USER# </document>
#
# Not-Preprocessed samples:
#  tf.Tensor([b'<author lang="es">\n\t<documents>\n\t\t<document><![CDATA[#USER# #USER# Pero a\xc3\xban ni las fiestas Patrias han empezado.. no chinguen! \xf0\x9f\x98\x82\xf0\x9f\x98\x82]]></document>\n\t\t<document><![CDATA[#USER# M\xc3\xa1s bien falta que haga rosca de reyes versi\xc3\xb3n pan de muerto.. \xf0\x9f\x98\x82\xf0\x9f\x98\x82\xf0\x9f\x98\x82]]></document>\n\t\t<document><![CDATA[\xc2\xa1\xc2\xa1Buenos d\xc3\xadas Aparicios!!]]></document>\n\t\t<document><![CDATA[#USER# Con todo y su ramita de apio para el deTox .. \xf0\x9f\x98\x86\xf0\x9f\x98\x86]]></document>\n\t\t<document><![CDATA[#USER# Siempre contenta, siempre entusiasta!! \xf0\x9f\xa4\xa3\xf0\x9f\xa4\xa3\xf0\x9f\x98\x82\xf0\x9f\x98\x82]]></document>\n\t\t<document><![CDATA[#HASHTAG# #HASHTAG# en fin de semana con Lobosho.. \xf0\x9f\xa4\xa3\xf0\x9f\x90\xaf\xf0\x9f\x90\xba\xf0\x9f\x90\xbb #URL#]]></document>\n\t\t<document><![CDATA[#USER# A veces me da curiosidad de ir, nada m\xc3\xa1s para saber que dicen.. \xf0\x9f\xa4\xa3]]></document>\n\t\t<document><![CDATA[#USER# Pues ya vamos en el Mexib\xc3\xbas y pues una maravilla de transporte.. \xf0\x9f\x98\x83\xf0\x9f\x98\x83\xf0\x9f\x98\x83]]></document>\n\t\t<document><![CDATA[#USER# \xc2\xa1\xc2\xa1Asi se va a extinguir la humanidad Alberto!! \xf0\x9f\x98\x86\xf0\x9f\x98\x86]]></document>\n\t\t<document><![CDATA[#USER# Buenos d\xc3\xadas Chef! \xe2\x9c\x8c\xf0\x9f\x8d\x9d\xf0\x9f\x8d\x9c\xf0\x9f\x8d\xb2]]></document>\n\t\t<document><![CDATA[#USER# #USER# Ajajajaja yo nada m\xc3\xa1s dec\xc3\xada.. \xf0\x9f\xa4\xa3\xf0\x9f\xa4\xa3\xf0\x9f\xa4\xa3]]></document>\n\t\t<document><![CDATA[#USER# #USER# *A Gel Xiomara le gusta esta publicaci\xc3\xb3n.. \xf0\x9f\x98\x86\xf0\x9f\x98\x86]]></document>\n\t\t<document><![CDATA[#USER# #USER# Y qu\xc3\xa9 tal si lo m\xc3\xado un perro? \xf0\x9f\x90\x95\xf0\x9f\xa4\x94\xf0\x9f\xa4\x94]]></document>\n\t\t<document><![CDATA[El Museo Internacional del #HASHTAG# es visita obligada cu\xc3\xa1ndo vienes a #HASHTAG# #USER#  \xf0\x9f\x98\x8d\xf0\x9f\xa4\xa9 #URL#]]></document>\n\t\t<document><![CDATA[Definitivamente el norte de M\xc3\xa9xico es como si fuera otro pais.\n\nHablan otro idioma y la gente tiene otras costumbres.. \xf0\x9f\xa4\xa3\xf0\x9f\xa4\xa3]]></document>\n\t\t<document><![CDATA[#USER# #USER# H\xc3\xadjole.. como que no se.. a\xc3\xban no me convence..\xf0\x9f\xa4\x94\xf0\x9f\xa4\x94]]></document>\n\t\t<document><![CDATA[#USER# #USER# Eso me recuerda.. Nunca inviertas la polaridad de un capacitor. Puede ser una experiencia terrible.. \xf0\x9f\x98\x82\xf0\x9f\x98\x85\xf0\x9f\x92\xa3\xf0\x9f\x92\xa5]]></document>\n\t\t<document><![CDATA[Inviertanle tantito a sus fiestas y festivales de m\xc3\xbasica. \n\nSalir de su pa\xc3\xads les da otra perspectiva del mundo, aunque sea para enfiestar...]]></document>\n\t\t<document><![CDATA[Son las 15:45 y aun parece que son las 10 de la ma\xc3\xb1ana.. #HASHTAG#]]></document>\n\t\t<document><![CDATA[RT #USER#: El nombramiento de Manuel Espino como coordinador de organizaciones sociales/civiles de AMLO es un golpe a quienes han\xe2\x80\xa6]]></document>\n\t\t<document><![CDATA[\xc2\xa1\xc2\xa1Buenos y frescos d\xc3\xadas!! \xf0\x9f\x98\x83\xf0\x9f\x98\x83]]></document>\n\t\t<document><![CDATA[Queridos #HASHTAG# #HASHTAG# de Asturias \xf0\x9f\x8e\x88\xf0\x9f\x8e\x81\xf0\x9f\x8e\x86\xf0\x9f\x8e\x89\xf0\x9f\x98\x84\xf0\x9f\x98\x84 #URL#]]></document>\n\t\t<document><![CDATA[El vuelo est\xc3\xa1 hasta la Madre.. #HASHTAG# \xf0\x9f\x98\x82\xf0\x9f\x98\x82\xf0\x9f\x98\x82 #URL#]]></document>\n\t\t<document><![CDATA[RT #USER#: Me pongo de pie por todos los que desde su trinchera aportan su granito de arena para que la comunidad #HASHTAG# viva e\xe2\x80\xa6]]></document>\n\t\t<document><![CDATA[Se siente bien bonito cuando lo sue\xc3\xb1os se materializan.. aunque los hayas sacado a meses sin intereses..\xf0\x9f\x98\x82\xf0\x9f\x98\x82]]></document>\n\t\t<document><![CDATA[Literal estoy hasta el Nido de Quetzalc\xc3\xb3atl.. \xf0\x9f\x90\ ...
# Preprocessed samples:
#
# 	<document> #USER# #USER# Pero aún ni las fiestas Patrias han empezado.. no chinguen! 😂😂 </document>
# 		<document> #USER# Más bien falta que haga rosca de reyes versión pan de muerto.. 😂😂😂 </document>
# 		<document> ¡¡Buenos días Aparicios!! </document>
# 		<document> #USER# Con todo y su ramita de apio para el deTox .. 😆😆 </document>
# 		<document> #USER# Siempre contenta, siempre entusiasta!! 🤣🤣😂😂 </document>
# 		<document>   en fin de semana con Lobosho.. 🤣🐯🐺🐻 #URL# </document>
# 		<document> #USER# A veces me da curiosidad de ir, nada más para saber que dicen.. 🤣 </document>
# 		<document> #USER# Pues ya vamos en el Mexibús y pues una maravilla de transporte.. 😃😃😃 </document>
# 		<document> #USER# ¡¡Asi se va a extinguir la humanidad Alberto!! 😆😆 </document>
# 		<document> #USER# Buenos días Chef! ✌🍝🍜🍲 </document>
# 		<document> #USER# #USER# Ajajajaja yo nada más decía.. 🤣🤣🤣 </document>
# 		<document> #USER# #USER# *A Gel Xiomara le gusta esta publicación.. 😆😆 </document>
# 		<document> #USER# #USER# Y qué tal si lo mío un perro? 🐕🤔🤔 </document>
# 		<document> El Museo Internacional del  es visita obligada cuándo vienes a  #USER#  😍🤩 #URL# </document>
# 		<document> Definitivamente el norte de México es como si fuera otro pais.
#
# Hablan otro idioma y la gente tiene otras costumbres.. 🤣🤣 </document>
# 		<document> #USER# #USER# Híjole.. como que no se.. aún no me convence..🤔🤔 </document>
# 		<document> #USER# #USER# Eso me recuerda.. Nunca inviertas la polaridad de un capacitor. Puede ser una experiencia terrible.. 😂😅💣💥 </document>
# 		<document> Inviertanle tantito a sus fiestas y festivales de música.
#
# Salir de su país les da otra perspectiva del mundo, aunque sea para enfiestar... </document>
# 		<document> Son las 15:45 y aun parece que son las 10 de la mañana..  </document>
# 		<document> RT #USER#: El nombramiento de Manuel Espino como coordinador de organizaciones sociales/civiles de AMLO es un golpe a quienes han… </document>
# 		<document> ¡¡Buenos y frescos días!! 😃😃 </document>
# 		<document> Queridos   de Asturias 🎈🎁🎆🎉😄😄 #URL# </document>
# 		<document> El vuelo está hasta la Madre..  😂😂😂 #URL# </document>
# 		<document> RT #USER#: Me pongo de pie por todos los que desde su trinchera aportan su granito de arena para que la comunidad  viva e… </document>
# 		<document> Se siente bien bonito cuando lo sueños se materializan.. aunque los hayas sacado a meses sin intereses..😂😂 </document>
# 		<document> Literal estoy hasta el Nido de Quetzalcóatl.. 🐍🌵🌵 </document>
# 		<document> Le voy a marcar hasta que la pinche bateria del celular se le acabe..😡😡 </document>
# 		<document> #USER# Te vas a pegar unos Mamelucos.. 😂😂😂😂  </document>
# 		<document> #USER# Hijo le no soy de IPhone mi Charlie. . Yo puro Motorola. .😃😃 </document>
# 		<document> Encabronado y lo que le sigue.. 😠😠😠 </document>
# 		<document> Los domingos también nos reunimos..  🍻🍻 #URL# </document>
# 		<document> #USER# Pos oye!! El alimento para las hijas es básico.. 😆😆 </document>
# 		<document> #USER# Pero a mí sí los DMs... 😆😆🤣🤣🤣🤣 </document>
# 		<document> ¡¡Buenos, fríos y nublados días!!
#
# ☁☁🌥☁☁☁ </document>
# 		<document> #USER# #USER# #USER# #USER# #USER# #USER# #USER# #USER# No salió mal la numeración?? 🤔🤔🤔 </document>
# 		<document> #USER# #USER# #USER# #USER# Por eso nos vamos hoy para llegar el 19 ..😂😂😂 </document>
# 		<document> #USER# Ajajaja duda uno cuál taco de canasta recién hecho amigo.. 🤣🤣🤣 </document>
# 		<document> #USER# Buenos!! 😄😄 </document>
# 		<document> #USER# #USER# El edificio de xola que se dañó en el sismo pasado sigue en pie pero cayeron un poco de escombros.. </document>
# 		<document> Buenos días! (@ Mastercard in Mexico City, DF w/ #USER#) #URL# </document>
# 		<document> #USER# ajajajaja lo malo es que ni un pedacito me compartieron..
# 😆😆 </document>
# 		<document> #USER# #USER# O ya de plano unas bonitas cartulinas 😂😂 </document>
# 		<document> ¡¡Buenos días!! A todos aquellos que vienen del Metro L2. Las Américas, Xola, Alamos y C. SCOP Siguen sin servicio en el metrobus L2. #URL# </document>
# 		<document> Ya que andamos en el   al menos conocer un poco más de los símbolos que nos identifican
#
# #URL# </document>
# 		<document> ¡¡Buenos días  !! Ya mañana es   ¿Que le van a pedir a Juan Gabriel? 😆😆 </document>
# 		<document> #USER# 😱🐉😂😂... Le íntegras el C-Ring 🤣🤣 </document>
# 		<document> #USER# Obvio yo soy el gatito patitas blancas.. 🤣🤣🤣 </document>
# 		<document> #USER# Yo mañana pongo en la jugada al Captain Morgan.. con todo y su twist de limón..😂😂 </document>
# 		<document> #USER# #USER# #USER# Super recomendable el lugar! 😄😄 </document>
# 		<document> #URL#
#
# Pues a mi si le gustó el video de la Katy Perry Prime.. aunque ya vimos cual será el disfraz para Halloween 🐯🐯 </document>
# 		<document> Oigan Parceros su país está bien bonito.. 🇨🇴🇨🇴🇨🇴  </document>
# 		<document> Estoy a dos de aplicar la de "Te lo dije" a uno de mis coworkers </document>
# 		<document> #USER# Y a la comadre mucho más!! 🤣🤣🤣 </document>
# 		<document> #USER# jajajaja siento que es como la de "El Burrito Sabanero" ajajajaja 😂😂 </document>
# 		<document> Si la andas cague, cague y cague, llega un momento en que se acaba el papel de baño.. </document>
# 		<document> #USER# Y uno aquí aún sin desayunar porque Don #USER# sigue dormido.. 😥😥 </document>
# 		<document> #USER# 🤣🤣🤣 Directo al Oscar como mejor actor de reparto.. 🤣🤣 </document>
# 		<document> Ese Rafita Márquez si se tomó muy en serio ser el "Crack" de la Selección.. 😹😹 </document>
# 		<document> #USER# #USER# No te preocupes, llegando las conecto.. 🤣🤣🤣🤣🤣🤣 </document>
# 		<document> #USER# #USER# La próxima es en Miami!! 😋😃😃🌴🌴 </document>
# 		<document> #USER# #USER# Muchas gracias Isaac!! 😄😄😄 </document>
# 		<document> #USER# Con 8hrs de sueño reglamentarias! 👏👏😂😂 </document>
# 		<document> Regla Godin  : Nunca de los nuncas guardes un tupper limpio con la tapa puesta.. ☝️ </document>
# 		<document> #USER# Ese fue el problema.. demasiada carga y la batería valió madres..😬😬 </document>
# 		<document> #USER# No se aprobó? 🙀🙀 </document>
# 		<document> Motivación: La decisión de realizar un esfuerzo para lograr un objetivo. </document>
# 		<document> RT #USER#: Lo bueno de las redes sociales es que le dan voz a la opinión de cualquier persona, lo malo de las redes sociales es que le d… </document>
# 		<document> #USER# #USER# Ora! que yo no fui.. fue la vecina.. 😂😂 </document>
# 		<document> RT #USER#: El orgullo gay no nació de la necesidad de celebrar el hecho de ser gay, sino de nuestro derecho a existir libres de pers… </document>
# 		<document> ¡¡ Ya que alguien saque la imagen de "Que tipo de Pan de Dulce eres de acuerdo a tu signo zodiacal" !! 😆😂 </document>
# 		<document> #USER# He ahí el problema de una mala planeación, terminas mal baratando un evento que pudo haber sido bueno..  </document>
# 		<document> #USER# Que de plano solo se la viven aquí.. 🤫🤷 </document>
# 		<document> #USER# Acá la cuidamos.. ¿A donde te vas? </document>
# 		<document> #USER# Ajajaja te quedan sólo 3 semanas según el calendario no oficial festivo 😂 </document>
# 		<document> ¡¡Buenos días Raza!! 🤣🤣 </document>
# 		<document> #USER# 🤣🤣🤣🤣🤣 pero así le hago a Nala y a Khora.. por qué a ti te infló otros cachetes.. 🤣🤣🤣😍😍  </document>
# 		<document> ¡¡Buenos y calurosos días!! Ya empieza a subir la temperatura en la  😃😃 </document>
# 		<document> Nunca falta en estos cursos el 1+ 😒😒 </document>
# 		<document> #USER# #USER# Wooeeeyyy el pan de muerto es una adicción!! 😂😂 </document>
# 		<document> #USER# Si por favor.. Gracias! </document>
# 		<document> #USER# Ya ni los muertos repetas.. 🤣🤣🤣 </document>
# 		<document> RT #USER#: Que bonito se siente cuando el cliente te felicita por tu trabajo.
#
# 😍😍😍😍😍😍😍 </document>
# 		<document> #USER# 🤣🤣🤣 el Abanico LGBT+ 🏳️‍🌈🏳️‍🌈 </document>
# 		<document> #USER# #USER# #USER# Nosotros en niños bien del CUM.. jajajajaja </document>
# 		<document> RT #USER#: No importa el destino del viaje, lo importante es recorrer el camino con la persona que amas. Te amo #USER#
# 😍😍😍👬👬… </document>
# 		<document> ¡¡Buenas tardes chavas!!
#
# *Me vale madres!.. en horario del ESTE ya son las 12... </document>
# 		<document> #USER# #URL#
#
# GM esta la 3ra posicion del ranking de Super Empresas y ocupa el 1er puesto en el sector Automotriz. #URL# </document>
# 		<document> ¡¡Buenos días Chakales del mundo!! </document>
# 		<document> #USER# #USER# Ánimo! ! Te mandamos porras y que quede muy bien! </document>
# 		<document> No mamen el final de "Another Life" me urge que salga la segunda temporada.. 😬😬👽👽🤖🤖 </document>
# 		<document> #USER# Muy buenos.. 😃😃 </document>
# 		<document> #USER# Hasta las 8 pero ya hay que irse levantado . 😆 </document>
# 		<document> #USER# Ya llegamos.. en intensas! 😜😜 </document>
# 		<document> Queridos hermanos podemos ir en paz..
#
# Nuestra junta de RH ha terminado...
#
# demos gracias al señor director.. </document>
# 		<document> #USER# No pues no.. ya ves.. 280 caracteres y no te sabes expresar bien ajajajajaja 😂😂😂😂 </document>
# 		<document> #USER# Según leo de varios creo literal los han timado con esa serie.. 😂😂 </document>
# 		<document> Hoy si fui, ingeniero, licenciado, comunicologo, mercadólogo, diseñador gráfico, madre y padre a la vez.. </document>
# 		<document> ¿Oye Nala? Ya vamos de regreso, pasas por nosotros al aeropuerto 😁😁 Cc #USER# #URL# </document>
# 		<document> Poderes de las Chachas fantásticas.. ¡Activense! 👯
#
# ¡¡Y pum!!  ¡¡la casa quedó super limpia!! 🏠 </document>
# 		<document> ¡¡Buenos días San Luis Potosí!! 😄😄😄 </document>

# %% [markdown]
# ## Models definition

# %%
# check gpu
cuda_available = torch.cuda.is_available()

print('Cuda available? ',cuda_available)

model_args = ClassificationArgs(num_train_epochs=1, 
                                      no_save=True, 
                                      no_cache=True, 
                                      overwrite_output_dir=True)

# English Model Training.
model_en = ClassificationModel("roberta", 
                                  'roberta-base', 
                                  args = model_args, 
                                  num_labels=2, 
                                  use_cuda=cuda_available)

# Spanish Model Training. 
model_es = ClassificationModel("roberta", 
                                  'PlanTL-GOB-ES/roberta-base-bne', 
                                  args = model_args, 
                                  num_labels=2, 
                                  use_cuda=cuda_available)

num_epochs_per_run = 10
num_runs = 5
# Out:
# Cuda available?  True
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the model checkpoint at PlanTL-GOB-ES/roberta-base-bne were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at PlanTL-GOB-ES/roberta-base-bne and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Training and evaluation of English model

# %%
runs_accuracy = []
for run in range(1,(num_runs+1)):
  epochs_accuracy=[]
  model_en = ClassificationModel("roberta", 
                                  'roberta-base', 
                                  args = model_args, 
                                  num_labels=2, 
                                  use_cuda=cuda_available)
  for epoch in range (0,num_epochs_per_run):
    # train model
    model_en.train_model(train_df_en)
    result_en, model_outputs_en, wrong_predictions_en = model_en.eval_model(test_df_en)
    # Results on english dataset.
    print(result_en)
    correct_predictions = result_en['tp']+result_en['tn']
    print("Correct predictions are: ",correct_predictions)
    total_predictions = result_en['tp']+result_en['tn']+result_en['fp']+result_en['fn']
    print("Total predictions are: ",total_predictions)
    accuracy = correct_predictions/total_predictions
    print("Accuracy on English test set is:",accuracy,"\n\n")
    epochs_accuracy.append(accuracy)

  print(epochs_accuracy)
  runs_accuracy.append(max(epochs_accuracy))

runs_accuracy.sort()
print("\n\n Over all runs maximum accuracies on English are:", runs_accuracy)
print("The median for English is:",runs_accuracy[2])
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3711842908553348, 'tp': 93, 'tn': 38, 'fp': 62, 'fn': 7, 'auroc': 0.72145, 'auprc': 0.6644350531580479, 'eval_loss': 0.65925537109375}
# Correct predictions are:  131
# Total predictions are:  200
# Accuracy on English test set is: 0.655
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3919570697385256, 'tp': 85, 'tn': 52, 'fp': 48, 'fn': 15, 'auroc': 0.7343999999999999, 'auprc': 0.7084592074918369, 'eval_loss': 0.6273086547851563}
# Correct predictions are:  137
# Total predictions are:  200
# Accuracy on English test set is: 0.685
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.31265317678104054, 'tp': 72, 'tn': 59, 'fp': 41, 'fn': 28, 'auroc': 0.7318500000000001, 'auprc': 0.6946273082573324, 'eval_loss': 0.6169549560546875}
# Correct predictions are:  131
# Total predictions are:  200
# Accuracy on English test set is: 0.655
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3891719503608543, 'tp': 84, 'tn': 53, 'fp': 47, 'fn': 16, 'auroc': 0.72395, 'auprc': 0.6895032052802721, 'eval_loss': 0.7224530029296875}
# Correct predictions are:  137
# Total predictions are:  200
# Accuracy on English test set is: 0.685
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.48038446141526137, 'tp': 76, 'tn': 72, 'fp': 28, 'fn': 24, 'auroc': 0.74945, 'auprc': 0.7039027263181882, 'eval_loss': 0.6361647033691407}
# Correct predictions are:  148
# Total predictions are:  200
# Accuracy on English test set is: 0.74
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.38783587594066987, 'tp': 79, 'tn': 59, 'fp': 41, 'fn': 21, 'auroc': 0.7261500000000001, 'auprc': 0.6981573278851396, 'eval_loss': 0.7834497833251953}
# Correct predictions are:  138
# Total predictions are:  200
# Accuracy on English test set is: 0.69
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.43368021295434656, 'tp': 78, 'tn': 65, 'fp': 35, 'fn': 22, 'auroc': 0.7485, 'auprc': 0.7288241926534752, 'eval_loss': 0.6615975189208985}
# Correct predictions are:  143
# Total predictions are:  200
# Accuracy on English test set is: 0.715
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.36262033381142117, 'tp': 74, 'tn': 62, 'fp': 38, 'fn': 26, 'auroc': 0.7217000000000001, 'auprc': 0.7059654629310984, 'eval_loss': 1.0279216384887695}
# Correct predictions are:  136
# Total predictions are:  200
# Accuracy on English test set is: 0.68
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.29798889489427005, 'tp': 53, 'tn': 76, 'fp': 24, 'fn': 47, 'auroc': 0.69715, 'auprc': 0.6623086125372074, 'eval_loss': 1.107418975830078}
# Correct predictions are:  129
# Total predictions are:  200
# Accuracy on English test set is: 0.645
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.37686493766715357, 'tp': 78, 'tn': 59, 'fp': 41, 'fn': 22, 'auroc': 0.7252500000000001, 'auprc': 0.6890934075797609, 'eval_loss': 1.3038994312286376}
# Correct predictions are:  137
# Total predictions are:  200
# Accuracy on English test set is: 0.685
#
#
# [0.655, 0.685, 0.655, 0.685, 0.74, 0.69, 0.715, 0.68, 0.645, 0.685]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.0, 'tp': 0, 'tn': 100, 'fp': 0, 'fn': 100, 'auroc': 0.6708000000000001, 'auprc': 0.632128728497823, 'eval_loss': 0.6928857421875}
# Correct predictions are:  100
# Total predictions are:  200
# Accuracy on English test set is: 0.5
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.36039326847972586, 'tp': 43, 'tn': 89, 'fp': 11, 'fn': 57, 'auroc': 0.7329000000000001, 'auprc': 0.6854291535222456, 'eval_loss': 0.64726806640625}
# Correct predictions are:  132
# Total predictions are:  200
# Accuracy on English test set is: 0.66
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4100461840523648, 'tp': 59, 'tn': 81, 'fp': 19, 'fn': 41, 'auroc': 0.7608, 'auprc': 0.731545138633769, 'eval_loss': 0.6086614990234375}
# Correct predictions are:  140
# Total predictions are:  200
# Accuracy on English test set is: 0.7
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.43002150161263436, 'tp': 72, 'tn': 71, 'fp': 29, 'fn': 28, 'auroc': 0.7333999999999999, 'auprc': 0.687459056839781, 'eval_loss': 0.6266627502441406}
# Correct predictions are:  143
# Total predictions are:  200
# Accuracy on English test set is: 0.715
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3444373818510708, 'tp': 59, 'tn': 75, 'fp': 25, 'fn': 41, 'auroc': 0.73945, 'auprc': 0.6855653845698974, 'eval_loss': 0.6603430938720704}
# Correct predictions are:  134
# Total predictions are:  200
# Accuracy on English test set is: 0.67
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.40128617695256397, 'tp': 74, 'tn': 66, 'fp': 34, 'fn': 26, 'auroc': 0.7445999999999999, 'auprc': 0.7157888968467562, 'eval_loss': 0.7094438552856446}
# Correct predictions are:  140
# Total predictions are:  200
# Accuracy on English test set is: 0.7
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.37046336899810156, 'tp': 71, 'tn': 66, 'fp': 34, 'fn': 29, 'auroc': 0.7380499999999999, 'auprc': 0.7144627840330796, 'eval_loss': 0.7072805023193359}
# Correct predictions are:  137
# Total predictions are:  200
# Accuracy on English test set is: 0.685
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3398804086005824, 'tp': 45, 'tn': 86, 'fp': 14, 'fn': 55, 'auroc': 0.6965499999999998, 'auprc': 0.6786782888795896, 'eval_loss': 1.319194049835205}
# Correct predictions are:  131
# Total predictions are:  200
# Accuracy on English test set is: 0.655
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3615384985502464, 'tp': 50, 'tn': 84, 'fp': 16, 'fn': 50, 'auroc': 0.7255000000000001, 'auprc': 0.6857341267508789, 'eval_loss': 1.463131275177002}
# Correct predictions are:  134
# Total predictions are:  200
# Accuracy on English test set is: 0.67
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.32839646383498095, 'tp': 49, 'tn': 82, 'fp': 18, 'fn': 51, 'auroc': 0.7172000000000001, 'auprc': 0.7173682788823124, 'eval_loss': 2.6491078543663025}
# Correct predictions are:  131
# Total predictions are:  200
# Accuracy on English test set is: 0.655
#
#
# [0.5, 0.66, 0.7, 0.715, 0.67, 0.7, 0.685, 0.655, 0.67, 0.655]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.0, 'tp': 100, 'tn': 0, 'fp': 100, 'fn': 0, 'auroc': 0.68805, 'auprc': 0.6389545574575235, 'eval_loss': 0.6892041015625}
# Correct predictions are:  100
# Total predictions are:  200
# Accuracy on English test set is: 0.5
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3125, 'tp': 79, 'tn': 51, 'fp': 49, 'fn': 21, 'auroc': 0.7173, 'auprc': 0.6521149081076363, 'eval_loss': 0.65452392578125}
# Correct predictions are:  130
# Total predictions are:  200
# Accuracy on English test set is: 0.65
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.37282185960072, 'tp': 81, 'tn': 55, 'fp': 45, 'fn': 19, 'auroc': 0.71915, 'auprc': 0.6794087681318379, 'eval_loss': 0.636156005859375}
# Correct predictions are:  136
# Total predictions are:  200
# Accuracy on English test set is: 0.68
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3606497548653875, 'tp': 71, 'tn': 65, 'fp': 35, 'fn': 29, 'auroc': 0.7386499999999999, 'auprc': 0.7029925574328373, 'eval_loss': 0.6238436889648438}
# Correct predictions are:  136
# Total predictions are:  200
# Accuracy on English test set is: 0.68
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.40785019354766533, 'tp': 97, 'tn': 35, 'fp': 65, 'fn': 3, 'auroc': 0.7224999999999999, 'auprc': 0.6687195876854293, 'eval_loss': 0.76042724609375}
# Correct predictions are:  132
# Total predictions are:  200
# Accuracy on English test set is: 0.66
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.31354747720298765, 'tp': 58, 'tn': 73, 'fp': 27, 'fn': 42, 'auroc': 0.7145000000000001, 'auprc': 0.6672399492178251, 'eval_loss': 0.807243537902832}
# Correct predictions are:  131
# Total predictions are:  200
# Accuracy on English test set is: 0.655
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.28365431446558775, 'tp': 56, 'tn': 72, 'fp': 28, 'fn': 44, 'auroc': 0.7184999999999999, 'auprc': 0.6684218368663564, 'eval_loss': 0.871140079498291}
# Correct predictions are:  128
# Total predictions are:  200
# Accuracy on English test set is: 0.64
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.2546384713967254, 'tp': 53, 'tn': 72, 'fp': 28, 'fn': 47, 'auroc': 0.66755, 'auprc': 0.6422241908827531, 'eval_loss': 1.6366810369491578}
# Correct predictions are:  125
# Total predictions are:  200
# Accuracy on English test set is: 0.625
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# ...
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3521369121510571, 'tp': 62, 'tn': 73, 'fp': 27, 'fn': 38, 'auroc': 0.6903499999999999, 'auprc': 0.6515919759333348, 'eval_loss': 0.68666015625}
# Correct predictions are:  135
# Total predictions are:  200
# Accuracy on English test set is: 0.675
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.11757927025044308, 'tp': 10, 'tn': 96, 'fp': 4, 'fn': 90, 'auroc': 0.7171000000000001, 'auprc': 0.6694995253116676, 'eval_loss': 0.68365234375}
# Correct predictions are:  106
# Total predictions are:  200
# Accuracy on English test set is: 0.53
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.18929799651846663, 'tp': 27, 'tn': 88, 'fp': 12, 'fn': 73, 'auroc': 0.6707500000000001, 'auprc': 0.6449968953646315, 'eval_loss': 0.67516357421875}
# Correct predictions are:  115
# Total predictions are:  200
# Accuracy on English test set is: 0.575
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3097316184757641, 'tp': 88, 'tn': 39, 'fp': 61, 'fn': 12, 'auroc': 0.7279500000000001, 'auprc': 0.7010502462684703, 'eval_loss': 0.655423583984375}
# Correct predictions are:  127
# Total predictions are:  200
# Accuracy on English test set is: 0.635
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3500175013126094, 'tp': 67, 'tn': 68, 'fp': 32, 'fn': 33, 'auroc': 0.726, 'auprc': 0.7119972898049651, 'eval_loss': 0.6125833129882813}
# Correct predictions are:  135
# Total predictions are:  200
# Accuracy on English test set is: 0.675
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3915891606942963, 'tp': 74, 'tn': 65, 'fp': 35, 'fn': 26, 'auroc': 0.7368500000000001, 'auprc': 0.6926910269106392, 'eval_loss': 0.6299049377441406}
# Correct predictions are:  139
# Total predictions are:  200
# Accuracy on English test set is: 0.695
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3700185013876156, 'tp': 69, 'tn': 68, 'fp': 32, 'fn': 31, 'auroc': 0.7191, 'auprc': 0.6676775246096669, 'eval_loss': 0.7043739318847656}
# Correct predictions are:  137
# Total predictions are:  200
# Accuracy on English test set is: 0.685
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.2884299752006152, 'tp': 52, 'tn': 76, 'fp': 24, 'fn': 48, 'auroc': 0.67505, 'auprc': 0.6461486846236631, 'eval_loss': 0.7956776428222656}
# Correct predictions are:  128
# Total predictions are:  200
# Accuracy on English test set is: 0.64
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3551698299029901, 'tp': 59, 'tn': 76, 'fp': 24, 'fn': 41, 'auroc': 0.69225, 'auprc': 0.6649362927453036, 'eval_loss': 0.9663988494873047}
# Correct predictions are:  135
# Total predictions are:  200
# Accuracy on English test set is: 0.675
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.27615793931820587, 'tp': 53, 'tn': 74, 'fp': 26, 'fn': 47, 'auroc': 0.66345, 'auprc': 0.6353456975033015, 'eval_loss': 1.285394458770752}
# Correct predictions are:  127
# Total predictions are:  200
# Accuracy on English test set is: 0.635
#
#
# [0.675, 0.53, 0.575, 0.635, 0.675, 0.695, 0.685, 0.64, 0.675, 0.635]
#
#
#  Over all runs maximum accuracies on English are: [0.68, 0.695, 0.705, 0.715, 0.74]
# The median for English is: 0.705

# %% [markdown]
# ## Training and evaluation of Spanish model

# %%
runs_accuracy = []
for run in range(1,(num_runs+1)):
  epochs_accuracy=[]
  model_es = ClassificationModel("roberta", 
                                  'PlanTL-GOB-ES/roberta-base-bne', 
                                  args = model_args, 
                                  num_labels=2, 
                                  use_cuda=cuda_available)
  for epoch in range (0,num_epochs_per_run):
    # train model
    model_es.train_model(train_df_es)
    result_es, model_outputs_es, wrong_predictions_es = model_es.eval_model(test_df_es)
    # Results on english dataset.
    print(result_es)
    correct_predictions = result_es['tp']+result_es['tn']
    print("Correct predictions are: ",correct_predictions)
    total_predictions = result_es['tp']+result_es['tn']+result_es['fp']+result_es['fn']
    print("Total predictions are: ",total_predictions)
    accuracy = correct_predictions/total_predictions
    print("Accuracy on Spanish test set is:",accuracy,"\n\n")
    epochs_accuracy.append(accuracy)

  print(epochs_accuracy)
  runs_accuracy.append(max(epochs_accuracy))

runs_accuracy.sort()
print("\n\n Over all runs maximum accuracies on Spanish are:", runs_accuracy)
print("The median for Spanish is:",runs_accuracy[2])
# Out:
# Some weights of the model checkpoint at PlanTL-GOB-ES/roberta-base-bne were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at PlanTL-GOB-ES/roberta-base-bne and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.31354747720298765, 'tp': 73, 'tn': 58, 'fp': 42, 'fn': 27, 'auroc': 0.7293, 'auprc': 0.7661263260837847, 'eval_loss': 0.6211614990234375}
# Correct predictions are:  131
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.655
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4566469241609873, 'tp': 64, 'tn': 81, 'fp': 19, 'fn': 36, 'auroc': 0.7651, 'auprc': 0.7963286363378251, 'eval_loss': 0.5715617370605469}
# Correct predictions are:  145
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.725
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.38394693349131337, 'tp': 36, 'tn': 95, 'fp': 5, 'fn': 64, 'auroc': 0.7811000000000001, 'auprc': 0.815588337078353, 'eval_loss': 0.8812052536010743}
# Correct predictions are:  131
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.655
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.41100820667619326, 'tp': 74, 'tn': 67, 'fp': 33, 'fn': 26, 'auroc': 0.77415, 'auprc': 0.789773160569805, 'eval_loss': 0.9589459896087646}
# Correct predictions are:  141
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.705
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.48541391272466294, 'tp': 61, 'tn': 86, 'fp': 14, 'fn': 39, 'auroc': 0.7905500000000001, 'auprc': 0.8084912995084035, 'eval_loss': 1.200692913532257}
# Correct predictions are:  147
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.735
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4623173950192375, 'tp': 68, 'tn': 78, 'fp': 22, 'fn': 32, 'auroc': 0.7599999999999999, 'auprc': 0.7425060590760162, 'eval_loss': 1.8533569651842117}
# Correct predictions are:  146
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.73
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4098229522188557, 'tp': 47, 'tn': 90, 'fp': 10, 'fn': 53, 'auroc': 0.752, 'auprc': 0.7725347453245831, 'eval_loss': 2.6193649625778197}
# Correct predictions are:  137
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.685
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.368135628719727, 'tp': 52, 'tn': 83, 'fp': 17, 'fn': 48, 'auroc': 0.73825, 'auprc': 0.7598486651614825, 'eval_loss': 2.744184640645981}
# Correct predictions are:  135
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.675
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4160560864577884, 'tp': 79, 'tn': 62, 'fp': 38, 'fn': 21, 'auroc': 0.77745, 'auprc': 0.8040041658958755, 'eval_loss': 2.746637716293335}
# Correct predictions are:  141
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.705
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.36028834606144605, 'tp': 70, 'tn': 66, 'fp': 34, 'fn': 30, 'auroc': 0.77075, 'auprc': 0.7790664339323308, 'eval_loss': 2.720299553871155}
# Correct predictions are:  136
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.68
#
#
# [0.655, 0.725, 0.655, 0.705, 0.735, 0.73, 0.685, 0.675, 0.705, 0.68]
# Some weights of the model checkpoint at PlanTL-GOB-ES/roberta-base-bne were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at PlanTL-GOB-ES/roberta-base-bne and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.42129464450569215, 'tp': 59, 'tn': 82, 'fp': 18, 'fn': 41, 'auroc': 0.75455, 'auprc': 0.7871936965658025, 'eval_loss': 0.5917596435546875}
# Correct predictions are:  141
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.705
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4375, 'tp': 57, 'tn': 85, 'fp': 15, 'fn': 43, 'auroc': 0.7828, 'auprc': 0.7914996393283662, 'eval_loss': 0.5779146575927734}
# Correct predictions are:  142
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.71
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4100461840523648, 'tp': 59, 'tn': 81, 'fp': 19, 'fn': 41, 'auroc': 0.76925, 'auprc': 0.7746833822545074, 'eval_loss': 0.629426498413086}
# Correct predictions are:  140
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.7
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4364357804719848, 'tp': 50, 'tn': 90, 'fp': 10, 'fn': 50, 'auroc': 0.7938999999999999, 'auprc': 0.807388435878631, 'eval_loss': 1.1065448236465454}
# Correct predictions are:  140
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.7
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.48038446141526137, 'tp': 72, 'tn': 76, 'fp': 24, 'fn': 28, 'auroc': 0.79285, 'auprc': 0.783929063639071, 'eval_loss': 0.9116646862030029}
# Correct predictions are:  148
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.74
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3419820832106588, 'tp': 38, 'tn': 91, 'fp': 9, 'fn': 62, 'auroc': 0.7945500000000002, 'auprc': 0.7939399085861825, 'eval_loss': 1.9371587443351745}
# Correct predictions are:  129
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.645
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.32006401920640226, 'tp': 67, 'tn': 65, 'fp': 35, 'fn': 33, 'auroc': 0.72725, 'auprc': 0.7394112741184902, 'eval_loss': 1.9340087389945984}
# Correct predictions are:  132
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.66
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4125032399483812, 'tp': 65, 'tn': 76, 'fp': 24, 'fn': 35, 'auroc': 0.76675, 'auprc': 0.7765396298527271, 'eval_loss': 2.158080332875252}
# Correct predictions are:  141
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.705
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.33267391956523024, 'tp': 37, 'tn': 91, 'fp': 9, 'fn': 63, 'auroc': 0.7789, 'auprc': 0.7776970823086085, 'eval_loss': 4.123030047416687}
# Correct predictions are:  128
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.64
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.36904156564712837, 'tp': 57, 'tn': 79, 'fp': 21, 'fn': 43, 'auroc': 0.75815, 'auprc': 0.7571292579142714, 'eval_loss': 2.826389253139496}
# Correct predictions are:  136
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.68
#
#
# [0.705, 0.71, 0.7, 0.7, 0.74, 0.645, 0.66, 0.705, 0.64, 0.68]
# Some weights of the model checkpoint at PlanTL-GOB-ES/roberta-base-bne were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at PlanTL-GOB-ES/roberta-base-bne and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.36262033381142117, 'tp': 62, 'tn': 74, 'fp': 26, 'fn': 38, 'auroc': 0.7421000000000001, 'auprc': 0.7707986016791817, 'eval_loss': 0.5931472778320312}
# Correct predictions are:  136
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.68
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4800960288096034, 'tp': 75, 'tn': 73, 'fp': 27, 'fn': 25, 'auroc': 0.7897500000000001, 'auprc': 0.8021681381676853, 'eval_loss': 0.5792454528808594}
# Correct predictions are:  148
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.74
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3521369121510571, 'tp': 62, 'tn': 73, 'fp': 27, 'fn': 38, 'auroc': 0.7297, 'auprc': 0.7381593981406608, 'eval_loss': 0.7105702209472656}
# Correct predictions are:  135
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.675
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.44141479464782035, 'tp': 76, 'tn': 68, 'fp': 32, 'fn': 24, 'auroc': 0.77, 'auprc': 0.775940090366505, 'eval_loss': 1.1372488117218018}
# Correct predictions are:  144
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.72
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3239199258358955, 'tp': 80, 'tn': 51, 'fp': 49, 'fn': 20, 'auroc': 0.7403000000000001, 'auprc': 0.7299320301221865, 'eval_loss': 1.53026850938797}
# Correct predictions are:  131
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.655
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.26384545277565086, 'tp': 86, 'tn': 37, 'fp': 63, 'fn': 14, 'auroc': 0.7473000000000001, 'auprc': 0.7385886982229077, 'eval_loss': 2.301968522071838}
# Correct predictions are:  123
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.615
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.29773758704137937, 'tp': 81, 'tn': 47, 'fp': 53, 'fn': 19, 'auroc': 0.7613499999999999, 'auprc': 0.7548485092413266, 'eval_loss': 2.388116649389267}
# Correct predictions are:  128
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.64
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4824181513244218, 'tp': 69, 'tn': 79, 'fp': 21, 'fn': 31, 'auroc': 0.7714499999999999, 'auprc': 0.7451024284220169, 'eval_loss': 1.8369342720508575}
# Correct predictions are:  148
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.74
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.352607714177008, 'tp': 45, 'tn': 87, 'fp': 13, 'fn': 55, 'auroc': 0.7423, 'auprc': 0.7626599466273498, 'eval_loss': 3.3803533029556276}
# Correct predictions are:  132
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.66
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.31265317678104054, 'tp': 72, 'tn': 59, 'fp': 41, 'fn': 28, 'auroc': 0.724, 'auprc': 0.7743154329328157, 'eval_loss': 2.696779688000679}
# Correct predictions are:  131
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.655
#
#
# [0.68, 0.74, 0.675, 0.72, 0.655, 0.615, 0.64, 0.74, 0.66, 0.655]
# Some weights of the model checkpoint at PlanTL-GOB-ES/roberta-base-bne were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...
# {'mcc': 0.30024028838453837, 'tp': 67, 'tn': 63, 'fp': 37, 'fn': 33, 'auroc': 0.73845, 'auprc': 0.7785230851143701, 'eval_loss': 2.9350942540168763}
# Correct predictions are:  130
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.65
#
#
# [0.665, 0.68, 0.625, 0.695, 0.665, 0.68, 0.725, 0.655, 0.665, 0.65]
# Some weights of the model checkpoint at PlanTL-GOB-ES/roberta-base-bne were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at PlanTL-GOB-ES/roberta-base-bne and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3909590258627204, 'tp': 66, 'tn': 73, 'fp': 27, 'fn': 34, 'auroc': 0.7347000000000001, 'auprc': 0.7606546476678668, 'eval_loss': 0.5993887329101563}
# Correct predictions are:  139
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.695
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.40089186286863654, 'tp': 46, 'tn': 90, 'fp': 10, 'fn': 54, 'auroc': 0.7666000000000001, 'auprc': 0.7918827626726801, 'eval_loss': 0.6141946411132813}
# Correct predictions are:  136
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.68
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4973045625740722, 'tp': 54, 'tn': 92, 'fp': 8, 'fn': 46, 'auroc': 0.8089500000000001, 'auprc': 0.8250330824714693, 'eval_loss': 0.6878627967834473}
# Correct predictions are:  146
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.73
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3618136134933163, 'tp': 73, 'tn': 63, 'fp': 37, 'fn': 27, 'auroc': 0.75925, 'auprc': 0.7730180410510531, 'eval_loss': 1.0843807363510132}
# Correct predictions are:  136
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.68
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.40074368623712175, 'tp': 58, 'tn': 81, 'fp': 19, 'fn': 42, 'auroc': 0.76375, 'auprc': 0.7812506106533281, 'eval_loss': 1.2508390629291535}
# Correct predictions are:  139
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.695
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.4510508024576013, 'tp': 61, 'tn': 83, 'fp': 17, 'fn': 39, 'auroc': 0.7781999999999999, 'auprc': 0.7925025743150982, 'eval_loss': 1.3871770071983338}
# Correct predictions are:  144
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.72
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3821343568257985, 'tp': 56, 'tn': 81, 'fp': 19, 'fn': 44, 'auroc': 0.7509, 'auprc': 0.7484851268487498, 'eval_loss': 2.1266755813360216}
# Correct predictions are:  137
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.685
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3551698299029901, 'tp': 76, 'tn': 59, 'fp': 41, 'fn': 24, 'auroc': 0.76545, 'auprc': 0.7873692125376927, 'eval_loss': 2.36850861787796}
# Correct predictions are:  135
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.675
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.3614784456460256, 'tp': 55, 'tn': 80, 'fp': 20, 'fn': 45, 'auroc': 0.7542, 'auprc': 0.7785575987650442, 'eval_loss': 3.0961649680137633}
# Correct predictions are:  135
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.675
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:602: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 0 of 1:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1443: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# {'mcc': 0.31001550116259685, 'tp': 65, 'tn': 66, 'fp': 34, 'fn': 35, 'auroc': 0.7278000000000001, 'auprc': 0.7282690318806229, 'eval_loss': 3.2119966745376587}
# Correct predictions are:  131
# Total predictions are:  200
# Accuracy on Spanish test set is: 0.655
#
#
# [0.695, 0.68, 0.73, 0.68, 0.695, 0.72, 0.685, 0.675, 0.675, 0.655]
#
#
#  Over all runs maximum accuracies on Spanish are: [0.725, 0.73, 0.735, 0.74, 0.74]
# The median for Spanish is: 0.735
