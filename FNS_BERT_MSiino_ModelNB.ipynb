# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/fake_news_spreaders_detection/blob/main/FNS_BERT_MSiino_ModelNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Automated Detection of Fake News Spreaders: An Evaluative Study of Transformers and SOTA Models on Multilingual Dataset.
# BERT Model, Training and Testing Notebook.
# Code by M. Siino.
#
# From the paper: "Automated Detection of Fake News Spreaders: An Evaluative Study of Transformers and SOTA Models on Multilingual Dataset." by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
# !pip install simpletransformers
# !pip install tensorboardx

import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf
import numpy as np
import torch
import pandas as pd

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from google.colab import files
from io import open
from pathlib import Path
from simpletransformers.classification import ClassificationModel, ClassificationArgs, MultiLabelClassificationModel, MultiLabelClassificationArgs
# Out:
# Collecting simpletransformers
#   Downloading simpletransformers-0.63.4-py3-none-any.whl (248 kB)
#      |████████████████████████████████| 248 kB 5.5 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.0.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2019.12.20)
# Collecting datasets
#   Downloading datasets-2.0.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 27.6 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.3 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 36.3 MB/s
# Collecting wandb>=0.10.32
#   Downloading wandb-0.12.11-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 34.1 MB/s
# Collecting transformers>=4.6.0
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 15.1 MB/s
# Collecting tokenizers
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 17.9 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.21.5)
# Collecting streamlit
#   Downloading streamlit-1.7.0-py2.py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 11.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2.23.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2.8.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.4.1)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (4.63.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (3.6.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 28.4 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.8 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 28.0 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=4.6.0->simpletransformers) (4.11.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers>=4.6.0->simpletransformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers>=4.6.0->simpletransformers) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (2.8.2)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 32.5 MB/s
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (1.15.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (5.4.8)
# Collecting setproctitle
#   Downloading setproctitle-1.2.2-cp37-cp37m-manylinux1_x86_64.whl (36 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (7.1.2)
# Collecting yaspin>=1.0.0
#   Downloading yaspin-2.1.0-py3-none-any.whl (18 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.8-py2.py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 38.9 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (2.3)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (3.17.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2021.10.8)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from yaspin>=1.0.0->wandb>=0.10.32->simpletransformers) (1.1.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 30.1 MB/s
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 35.4 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (6.0.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.70.12.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.3.4)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.2.0-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 32.3 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 19.6 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 37.0 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.4 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->simpletransformers) (2.0.12)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 45.7 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=4.6.0->simpletransformers) (3.7.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->simpletransformers) (2018.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.6.0->simpletransformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->simpletransformers) (3.1.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (7.1.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (1.5.1)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (5.1.1)
# Collecting watchdog
#   Downloading watchdog-2.1.6-py3-none-manylinux2014_x86_64.whl (76 kB)
#      |████████████████████████████████| 76 kB 4.4 MB/s
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.8.1)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 46.8 MB/s
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 45.7 MB/s
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 29.0 MB/s
# Requirement already satisfied: semver in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (2.13.0)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.2.4)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.2.0)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (4.3.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.11.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers) (5.4.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (7.6.5)
# Collecting ipykernel>=5.1.2
#   Downloading ipykernel-6.9.2-py3-none-any.whl (130 kB)
#      |████████████████████████████████| 130 kB 48.4 MB/s
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (5.1.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.0.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.1.3)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.3.5)
# Collecting ipython>=7.23.1
#   Downloading ipython-7.32.0-py3-none-any.whl (793 kB)
#      |████████████████████████████████| 793 kB 44.4 MB/s
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.5.4)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.28-py3-none-any.whl (380 kB)
#      |████████████████████████████████| 380 kB 47.0 MB/s
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (57.4.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.18.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (2.6.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.0.2)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->altair>=3.2.0->streamlit->simpletransformers) (2.0.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (22.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.3.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.8.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.1.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.6.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.5.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.35.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.44.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (0.37.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->simpletransformers) (3.3.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (3.2.0)
# Building wheels for collected packages: pathtools, seqeval, blinker
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=f172a4fa441e2beb3d4d87cdecab421dd7cf7914e6a0b309c5e200dc7473ebe0
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=34ad52562e150401e164f6799f2485408a6f2011d13a362916480e4e05bed138
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for blinker (setup.py) ... done
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=19e33e831dcce64e8dae8a817d273552a24112eb0e4b1b78250957b50a65cdaa
#   Stored in directory: /root/.cache/pip/wheels/22/f5/18/df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
# Successfully built pathtools seqeval blinker
# Installing collected packages: prompt-toolkit, ipython, ipykernel, urllib3, multidict, frozenlist, yarl, smmap, asynctest, async-timeout, aiosignal, pyyaml, gitdb, fsspec, aiohttp, yaspin, xxhash, watchdog, validators, toml, tokenizers, shortuuid, setproctitle, sentry-sdk, sacremoses, responses, pympler, pydeck, pathtools, huggingface-hub, GitPython, docker-pycreds, blinker, base58, wandb, transformers, streamlit, seqeval, sentencepiece, datasets, simpletransformers
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Attempting uninstall: ipython
#     Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.28 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.9.2 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.32.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed GitPython-3.1.27 aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 base58-2.1.1 blinker-1.4 datasets-2.0.0 docker-pycreds-0.4.0 frozenlist-1.3.0 fsspec-2022.2.0 gitdb-4.0.9 huggingface-hub-0.4.0 ipykernel-6.9.2 ipython-7.32.0 multidict-6.0.2 pathtools-0.1.2 prompt-toolkit-3.0.28 pydeck-0.7.1 pympler-1.0.1 pyyaml-6.0 responses-0.18.0 sacremoses-0.0.49 sentencepiece-0.1.96 sentry-sdk-1.5.8 seqeval-1.2.2 setproctitle-1.2.2 shortuuid-1.0.8 simpletransformers-0.63.4 smmap-5.0.0 streamlit-1.7.0 tokenizers-0.11.6 toml-0.10.2 transformers-4.17.0 urllib3-1.25.11 validators-0.18.2 wandb-0.12.11 watchdog-2.1.6 xxhash-3.0.0 yarl-1.7.2 yaspin-2.1.0
# Collecting tensorboardx
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 5.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorboardx) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardx) (1.21.5)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardx) (3.17.3)
# Installing collected packages: tensorboardx
# Successfully installed tensorboardx-2.5

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
# Url obtained starting from this: https://drive.google.com/file/d/19ZcqEv88euKB71HfAWjTGN3uCKp2qsfP/ and forcing export=download.
urlTrainingSet = "https://github.com/marco-siino/fake_news_spreaders_detection/raw/main/dataset/pan20-author-profiling-training-2020-02-23.zip"
urlTestSet="https://github.com/marco-siino/fake_news_spreaders_detection/raw/main/dataset/pan20-author-profiling-test-2020-02-23.zip"

training_set = tf.keras.utils.get_file("pan20-author-profiling-training-2020-02-23.zip", urlTrainingSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')
test_set = tf.keras.utils.get_file("pan20-author-profiling-test-2020-02-23.zip", urlTestSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

training_set_dir = os.path.join(os.path.dirname(training_set), 'pan20-author-profiling-training-2020-02-23')
test_set_dir = os.path.join(os.path.dirname(test_set), 'pan20-author-profiling-test-2020-02-23')

print(training_set)
print(training_set_dir)

# !ls -A
# Out:
# Downloading data from https://github.com/marco-siino/fake_news_spreaders_detection/raw/main/dataset/pan20-author-profiling-training-2020-02-23.zip
# 3096576/3094459 [==============================] - 0s 0us/step
# 3104768/3094459 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/fake_news_spreaders_detection/raw/main/dataset/pan20-author-profiling-test-2020-02-23.zip
# 2138112/2135236 [==============================] - 0s 0us/step
# 2146304/2135236 [==============================] - 0s 0us/step
# ./pan20-author-profiling-training-2020-02-23.zip
# ./pan20-author-profiling-training-2020-02-23
# .config
# __MACOSX
# pan20-author-profiling-test-2020-02-23
# pan20-author-profiling-test-2020-02-23.zip
# pan20-author-profiling-training-2020-02-23
# pan20-author-profiling-training-2020-02-23.zip
# sample_data

# %% [markdown]
# ## Build folders hierarchy to use Keras folders preprocessing function.

# %%
### Training Folders. ###

# First level directory.
if not os.path.exists('train_dir_en'):
    os.makedirs('train_dir_en')
if not os.path.exists('train_dir_es'):
    os.makedirs('train_dir_es')

# Class labels directory.
if not os.path.exists('train_dir_en/0'):
    os.makedirs('train_dir_en/0')
if not os.path.exists('train_dir_es/0'):
    os.makedirs('train_dir_es/0')
if not os.path.exists('train_dir_en/1'):
    os.makedirs('train_dir_en/1')
if not os.path.exists('train_dir_es/1'):
    os.makedirs('train_dir_es/1')

# Make Py variables.
train_dir='train_dir_'

## Test Folders. ##
# First level directory.
if not os.path.exists('test_dir_en'):
    os.makedirs('test_dir_en')
if not os.path.exists('test_dir_es'):
    os.makedirs('test_dir_es')

# Class labels directory.
if not os.path.exists('test_dir_en/0'):
    os.makedirs('test_dir_en/0')
if not os.path.exists('test_dir_es/0'):
    os.makedirs('test_dir_es/0')
if not os.path.exists('test_dir_en/1'):
    os.makedirs('test_dir_en/1')
if not os.path.exists('test_dir_es/1'):
    os.makedirs('test_dir_es/1')

# Make Py variables.
test_dir='test_dir_'

# !ls -A
# Out:
# .config						sample_data
# __MACOSX					test_dir_en
# pan20-author-profiling-test-2020-02-23		test_dir_es
# pan20-author-profiling-test-2020-02-23.zip	train_dir_en
# pan20-author-profiling-training-2020-02-23	train_dir_es
# pan20-author-profiling-training-2020-02-23.zip

# %% [markdown]
# ## Set language and directory paths.

# %%
# Set en and es train_dir and test_dir paths.
language='es'

truth_file_training_dir_es=training_set_dir+'/'+language+'/'
truth_file_training_path_es = truth_file_training_dir_es+'truth.txt'

truth_file_test_dir=test_set_dir
truth_file_test_path_es = truth_file_test_dir+'/'+language+'.txt'


language='en'

truth_file_training_dir_en=training_set_dir+'/'+language+'/'
truth_file_training_path_en = truth_file_training_dir_en+'truth.txt'

truth_file_test_path_en = truth_file_test_dir+'/'+language+'.txt'

# %% [markdown]
# ## Read truth.txt to organize training dataset folders.

# %%
# Organize EN folders.
language='en'
# Open the file truth.txt with read only permit.
f = open(truth_file_training_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_training_dir_en+fNameXml):
      os.rename(truth_file_training_dir_en+fNameXml, './train_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

language='es'
# Organize ES folders.
# Open the file truth.txt with read only permit.
f = open(truth_file_training_path_es, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_training_dir_es+fNameXml):
      os.rename(truth_file_training_dir_es+fNameXml, './train_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# %% [markdown]
# ## Read truth.txt to organize test dataset folders.

# %%
#Organize EN folders.
language='en'
# Open the file truth.txt with read only permit.
f = open(truth_file_test_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_dir+'/'+language+'/'+fNameXml, './test_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

#Organize EN folders.
language='es'
# Open the file truth.txt with read only permit.
f = open(truth_file_test_path_es, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_dir+'/'+language+'/'+fNameXml, './test_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# %% [markdown]
# ## Function to pre-process source text.

# %%
def custom_standardization(input_data):
  tag_open_CDATA_removed = tf.strings.regex_replace(input_data, '<\!\[CDATA\[', ' ')
  tag_closed_CDATA_removed = tf.strings.regex_replace(tag_open_CDATA_removed,'\]{1,}>', ' ')
  tag_author_lang_es_removed = tf.strings.regex_replace(tag_closed_CDATA_removed,'<author lang="es">', ' ')
  tag_author_lang_en_removed = tf.strings.regex_replace(tag_author_lang_es_removed,'<author lang="en">', ' ')
  tag_closed_author_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'</author>', ' ')
  tag_open_documents_removed = tf.strings.regex_replace(tag_closed_author_removed,'<documents>\n(\t){0,2}', '')
  output_data = tf.strings.regex_replace(tag_open_documents_removed,'</documents>\n(\t){0,2}', ' ')
  return output_data

# %% [markdown]
# ## Building the dataset.

# %%
batch_size=1

# Build the dataset for Spanish.
language='es'

raw_train_ds_es = tf.keras.preprocessing.text_dataset_from_directory(
    train_dir+language, 
    batch_size=batch_size, 
    #validation_split=0.0, 
    #subset='training', 
    shuffle='false',
    seed=1
    )

raw_test_ds_es = tf.keras.preprocessing.text_dataset_from_directory(
    test_dir+language, 
    batch_size=batch_size,
    shuffle='false'
    )


# Build the dataset for Spanish.
language='en'

raw_train_ds_en = tf.keras.preprocessing.text_dataset_from_directory(
    train_dir+language, 
    batch_size=batch_size, 
    #validation_split=0.0, 
    #subset='training', 
    shuffle='false',
    seed=1
    )

raw_test_ds_en = tf.keras.preprocessing.text_dataset_from_directory(
    test_dir+language, 
    batch_size=batch_size,
    shuffle='false'
    )
# Out:
# Found 300 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.
# Found 300 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.

# %% [markdown]
# ## Convert DSs to Pandas Dataframe

# %%
# Convert English dataset.
train_df_en = [] # will contain text and label
for element in raw_train_ds_en:
  authorDocument=element[0]
  label=int(element[1].numpy())
  #print(authorDocument[0])
  text = custom_standardization(authorDocument[0].numpy()).numpy().decode('UTF-8')
  train_df_en.append({
      'text':text,
      'label':label
  })
train_df_en = pd.DataFrame(train_df_en)
test_df_en = [] # will contain text and label
for element in raw_test_ds_en:
  authorDocument=element[0]
  label=int(element[1].numpy())
  #print(authorDocument[0])
  text = custom_standardization(authorDocument[0].numpy()).numpy().decode('UTF-8')
  test_df_en.append({
      'text':text,
      'label':label
  })
test_df_en = pd.DataFrame(test_df_en)

# Convert Spanish dataset.
train_df_es = [] # will contain text and label
for element in raw_train_ds_es:
  authorDocument=element[0]
  label=int(element[1].numpy())
  #print(authorDocument[0])
  text = custom_standardization(authorDocument[0].numpy()).numpy().decode('UTF-8')
  train_df_es.append({
      'text':text,
      'label':label
  })
train_df_es = pd.DataFrame(train_df_es)
test_df_es = [] # will contain text and label
for element in raw_test_ds_es:
  authorDocument=element[0]
  label=int(element[1].numpy())
  #print(authorDocument[0])
  text = custom_standardization(authorDocument[0].numpy()).numpy().decode('UTF-8')
  test_df_es.append({
      'text':text,
      'label':label
  })
test_df_es = pd.DataFrame(test_df_es)

# %% [markdown]
# ## Print some RAW and preprocessed samples (No need to execute)

# %%
for idx, element in enumerate(raw_train_ds_es):
  if idx>1: break
  authorDocument=element[0]
  label=element[1]
  temp = custom_standardization(authorDocument[0].numpy()).numpy().decode('UTF-8')
  print("Not-Preprocessed samples: \n",authorDocument)
  print("Preprocessed samples: \n",temp)
# Out:
# Not-Preprocessed samples:
#  tf.Tensor([b'<author lang="es">\n\t<documents>\n\t\t<document><![CDATA[Movimiento 15M #URL#]]></document>\n\t\t<document><![CDATA[RT #USER#: Alicia , peque\xc3\xb1a... cuanto horror. Nuestro cuerpo roto, al fin de la jornada, lagrimea... cuanto dolor!! #HASHTAG#\xe2\x80\xa6]]></document>\n\t\t<document><![CDATA[He publicado una foto nueva en Facebook #URL#]]></document>\n\t\t<document><![CDATA[El enchufismo en las universidades es tan enorme que cuando los enchufados de grado m\xc3\xa1ximo se jubilan consiguen... #URL#]]></document>\n\t\t<document><![CDATA[He publicado una foto nueva en Facebook #URL#]]></document>\n\t\t<document><![CDATA[RT #USER#: #USER# El que de alguna manera ultraje o menosprecie la Bandera, el Escudo y el Himno de la Rep\xc3\xbablica ser castigado d\xe2\x80\xa6]]></document>\n\t\t<document><![CDATA[#HASHTAG#, espero que tu tesorero sea m\xc3\xa1s leal que #HASHTAG# \nMenos mal que ibais a regenerar la pol\xc3\xadtica en Espa\xc3\xb1a.\nSiento mariposas en el est\xc3\xb3mago al pensar en ti y en los que han apoyado vuestra gesti\xc3\xb3n a nivel interno en #USER#]]></document>\n\t\t<document><![CDATA[He publicado una foto nueva en Facebook #URL#]]></document>\n\t\t<document><![CDATA[He publicado una foto nueva en Facebook #URL#]]></document>\n\t\t<document><![CDATA[Una asesora de Carmena a una familia desahuciada con 4 hijos: "Iros a darle la vara a Cifuentes" #URL#]]></document>\n\t\t<document><![CDATA[He publicado una foto nueva en Facebook #URL#]]></document>\n\t\t<document><![CDATA[RT #USER#: RT jpoveda1977: #HASHTAG# hay va enterrando escuela para tods Escuelapublicad basespodemosclm Sabr\xe2\x80\xa6 htt\xe2\x80\xa6]]></document>\n\t\t<document><![CDATA[Sueldos \xc3\xadnfimos. Alojamientos infrahumanos. Contratos enga\xc3\xb1osos. Compa\xc3\xb1eros y jefes recelosos. Medio millar de... #URL#]]></document>\n\t\t<document><![CDATA[He publicado una foto nueva en Facebook #URL#]]></document>\n\t\t<document><![CDATA[He publicado una foto nueva en Facebook #URL#]]></document>\n\t\t<document><![CDATA[En el punto de mira, el conglomerado empresarial auton\xc3\xb3mico tejido en a\xc3\xb1os de inercia y descontrol pol\xc3\xadtico, un... #URL#]]></document>\n\t\t<document><![CDATA[#USER# estoy contigo juan , me parece que nadie se merece lo que a t\xc3\xad te han dicho.Eres un profesional, otros est\xc3\xa1 por ver.]]></document>\n\t\t<document><![CDATA[He publicado una foto nueva en Facebook #URL#]]></document>\n\t\t<document><![CDATA[El edil est\xc3\xa1 siendo investigado por los delitos de prevaricaci\xc3\xb3n y tr\xc3\xa1fico de influencias y se le acusa junto a otros ediles de haber colocar en el Ayuntamiento de Arcos a un... #URL#]]></document>\n\t\t<document><![CDATA[El Instituto Cervantes vuelve a las andadas. La cobertura de los altos cargos de la instituci\xc3\xb3n p\xc3\xbablica por parte de su nuevo director, Juan Manuel Bonet, ha perpetuado... #URL#]]></document>\n\t\t<document><![CDATA[J. A. se present\xc3\xb3 ante un notario y le pidi\xc3\xb3 que levantase acta de un futurible. Y le facilit\xc3\xb3 14 nombres, de los... #URL#]]></document>\n\t\t<document><![CDATA[RT #USER#: #HASHTAG# y ganar\xc3\xa1s el cielo, creando ovejas, creando siervos. #URL#]]></document>\n\t\t<document><![CDATA[Pura manipulaci\xc3\xb3n de masas. Insisto, el manejo de las televisiones por periodistas excelentemente pagados ha... #URL#]]></document>\n\t\t<document><![CDATA[RT #USER#: En la escuela laicismo en la iglesia catolicismo cada cual en su sitio #HASHTAG#]]></document>\n\t\t<document><![CDATA[He publicado una foto nueva en Facebook #URL#]]></document>\n\t\t<document><![CDATA[Es todo un honor amigo y compa\xc3\xb1ero #USER# \nCon personas como t\xc3\xba que siempre pugnan por defender los DDHH todo es posible. #URL#]]></document>\n\t\t<document><![CDATA[RT #USER#: El pueblo DECIDE! Por una Venezuela \xf0\x9f\x87\xbb\xf0\x9f\x87\xaa Libre y Dem\xc3\xb3crata ! #URL#]]></document>\n\t\t<document><![CDATA[He publicado u ...
# Preprocessed samples:
#
# 	<document> Movimiento 15M #URL# </document>
# 		<document> RT #USER#: Alicia , pequeña... cuanto horror. Nuestro cuerpo roto, al fin de la jornada, lagrimea... cuanto dolor!! #HASHTAG#… </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> El enchufismo en las universidades es tan enorme que cuando los enchufados de grado máximo se jubilan consiguen... #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> RT #USER#: #USER# El que de alguna manera ultraje o menosprecie la Bandera, el Escudo y el Himno de la República ser castigado d… </document>
# 		<document> #HASHTAG#, espero que tu tesorero sea más leal que #HASHTAG#
# Menos mal que ibais a regenerar la política en España.
# Siento mariposas en el estómago al pensar en ti y en los que han apoyado vuestra gestión a nivel interno en #USER# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> Una asesora de Carmena a una familia desahuciada con 4 hijos: "Iros a darle la vara a Cifuentes" #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> RT #USER#: RT jpoveda1977: #HASHTAG# hay va enterrando escuela para tods Escuelapublicad basespodemosclm Sabr… htt… </document>
# 		<document> Sueldos ínfimos. Alojamientos infrahumanos. Contratos engañosos. Compañeros y jefes recelosos. Medio millar de... #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> En el punto de mira, el conglomerado empresarial autonómico tejido en años de inercia y descontrol político, un... #URL# </document>
# 		<document> #USER# estoy contigo juan , me parece que nadie se merece lo que a tí te han dicho.Eres un profesional, otros está por ver. </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> El edil está siendo investigado por los delitos de prevaricación y tráfico de influencias y se le acusa junto a otros ediles de haber colocar en el Ayuntamiento de Arcos a un... #URL# </document>
# 		<document> El Instituto Cervantes vuelve a las andadas. La cobertura de los altos cargos de la institución pública por parte de su nuevo director, Juan Manuel Bonet, ha perpetuado... #URL# </document>
# 		<document> J. A. se presentó ante un notario y le pidió que levantase acta de un futurible. Y le facilitó 14 nombres, de los... #URL# </document>
# 		<document> RT #USER#: #HASHTAG# y ganarás el cielo, creando ovejas, creando siervos. #URL# </document>
# 		<document> Pura manipulación de masas. Insisto, el manejo de las televisiones por periodistas excelentemente pagados ha... #URL# </document>
# 		<document> RT #USER#: En la escuela laicismo en la iglesia catolicismo cada cual en su sitio #HASHTAG# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> Es todo un honor amigo y compañero #USER#
# Con personas como tú que siempre pugnan por defender los DDHH todo es posible. #URL# </document>
# 		<document> RT #USER#: El pueblo DECIDE! Por una Venezuela 🇻🇪 Libre y Demócrata ! #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> El Gobierno del PP del municipio juguetero de Ibi (24.000 habitantes) ha escalado hasta la cima de la negra... #URL# </document>
# 		<document> RT #USER#: RT BasesPodemosCyL: En Bases Podemos CLM estamos con Seseña  #HASHTAG# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> 😂😂😂😂 Juan, ni caso 😉 #URL# </document>
# 		<document> Nick Clegg ha pedido perdón a sus votantes. El número dos del Gobierno británico y líder de los liberaldemócratas... #URL# </document>
# 		<document> RT #USER#: #USER# Amigo #USER# regurgitas como el típico “intelectual” de izquierdas tan cargado de buenas intenciones com de p… </document>
# 		<document> RT #USER#: Las multinacionales un día fueron pequeñas empresas que nacieron en legislaciones favorables al crecimiento en su sector. </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> RT #USER#: RT BasesPodemosCyL: #HASHTAG# . Ni catecismo ni religión, laicismo en la educación. </document>
# 		<document> RT #USER#: Menudo desastre. La compra fue una decisión privada y privada debe seguir. Al someterla a plebiscito, si pierden, quedan… </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> RT #USER#: #HASHTAG# hablar de machismo cuando su líder, Pablo Iglesias dijo: "La azotaría hasta que sangre" sobre una peri… </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> El sistema capitalista definitivamente ha muerto, es como un organismo biológico al que se le suministra oxígeno... #URL# </document>
# 		<document> Fallece Carme Chacón,  ex ministra de defensa socialista.
# Como socialista de corazón lamento su  muerte.
# #URL# </document>
# 		<document> Los contratos a dedo ( que lo son) esconden mucho más , la enorme corrupción institucional es un crimen en masa,... #URL# </document>
# 		<document> Francisco Núñez, diputado regional del PP en las Cortes de Castilla-La Mancha y hombre de confianza de María... #URL# </document>
# 		<document> Podemos Gandia: la realidad supera a la ficción • /r/podemos #URL# </document>
# 		<document> RT #USER#: EspaÑa ese pais en el que te amnistian si defraudas a hacienda y eres un criminal si protestas por ello. #HASHTAG#  ... </document>
# 		<document> La educación y la cultura deben ser pilares fundamentales  , no permitamos por ningún medio que partidos... #URL# </document>
# 		<document> Cuanto más lo pienso me doy cuenta que eso que decía Darwin siendo verdad hoy no se aplica, parece que el programa... #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> RT #USER#: Autoorganizacion #HASHTAG# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> El también diputado de Economía quiere presentar las citadas cuentas el próximo viernes, con lo que el presupuesto de la institución para la orquesta se hará público... #URL# </document>
# 		<document> Amigos os tengo que decir una cosa y aunque suene muy paternalista o incluso pedante os aseguro que es la auténtica y real verdad me da igual lo que piensen los demás.
# Eso de las izquierdas y de las derechas es... #URL# </document>
# 		<document> RT #USER#: #USER# Hola compa,
# Tal y como he dicho cuando se me ha preguntado, y tal y como aparece en la web oficial del C… </document>
# 		<document> RT #USER#: Estudiar y rezar no es algo del siglo XXI   #HASHTAG# </document>
# 		<document> Qué diferencia a esta sociedad actual de la de hace cincuenta años ?... #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> Es muy útil que leais esto para saber de la "vocación que tiene éstos nuestros políticos.No os adelanto nada... #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> RT #USER#: ECHENIQUE: DIMITE Y DEJA DE AVERGONZAR A ARAGÓN
# Es ya un ruego. Por higiene mental. Ni siquiera tu propia gente... https… </document>
# 		<document> RT #USER#: Con el PP nos iba fatal, y con Page igual de mal. Laicismo y cambio en CLM ya.
#  #HASHTAG# </document>
# 		<document> quién dice que los funcionarios no son enchufados , qué supuesta carrera es esta que les premia con un puesto de... #URL# </document>
# 		<document> A que nadie se entera de las protestas llevadas a cab por los trabajadores de EL CORTE INGLÉS?.......LOS MEDIOS... #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> Ahora la sentencia del TSJA evidencia la "irregular actuación del tribunal que habría permitido la filtración y... #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> RT #USER#: #USER# #USER# #USER# #USER# #USER# #USER# #USER# #USER# Es que entre la… </document>
# 		<document> Es siempre un placer que personas relevantes como Nativel Preciado se hagan eco de la página de Facebook que yo... #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> Uno de los mensajes intervenidos se refiere a una conversación entre directivos de Viaqua en la que se alude a la... #URL# </document>
# 		<document> RT #USER#: Estupenda proyección de #HASHTAG# en Nerja, con 250 personas llenando la sala. Gracias #USER# y demás ami… </document>
# 		<document> El copago es ya un hecho , ya sólo nos queda apostar si va a ser más duro para los ciudadans en genera de lo que... #URL# </document>
# 		<document> La democracia no existe ha sido substituida por una plutocracia en la que los poderes económicos han adquirido... #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> Ya tenemos a camps en la calle .Esto está cambiando y sólo es el principio.Un abrazo a todos!!!!De todas maneras... #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> "Para gestionar la diversidad no basta con decirlo y seguir a continuación aplicando doctrinas mil veces fracasadas. Por ejemplo, el descarado hiperliderazgo ultrapersonalista disfrazado de humilde amor al pueblo, los trabajadores/as etc., etc". #URL# </document>
# 		<document> RT #USER#: #USER# #USER# #HASHTAG# lo mismo digo,fuera ese invento de vividores </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> RT #USER#: Si con Page se pierde el laicismo, también perderá el Gobierno de la región. Que no cuente con Podemos #HASHTAG#… </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> RT #USER#: #USER# #USER# #USER# #USER# #USER#  SR.Armada está Srta .Tendría que dimitir . Por dig… </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> En concreto, y tras analizar en profundidad una denuncia previa del PSOE local, Anticorrupción acusa a Ruiz... #URL# </document>
# 		<document> El nombre de Irene Montero aparece en todas las encuestas internas cuando Podemos prepara la sucesión femenina a Pablo Iglesias. “Estoy convencida de que la próxima secretaria... #URL# </document>
# 		<document> La devaluación  de la economía de una sociedad se puede hacer de dos maneras: La primera devaluando la moneda (en... #URL# </document>
# 		<document> Brillante y premonitorio artículo del año 2015 :
#
# "Por mucho menos de lo que hace Podemos en España, el régimen chavista tacha de “golpistas” a los... #URL# </document>
# 		<document> He publicado una foto nueva en Facebook #URL# </document>
# 		<document> Spanish RevolutionPara qué formarse, para qué tener talento, cómo se puede uno ganar un puesto si ni siquiera te... #URL# </document>
# 		<document> La sociedad española no ha evolucionado , se mantiene en sus defectos históricos enormes desde antes del reinado... #URL# </document>
# 		<document> RT #USER#: Movistar trincó a Diputación d Gipuzkoa miles d €.? Con Euskaltel pagará 40.000€ menos al año. Q ha pasado? Ineptitud?… </document>
# 		<document> "En EE UU no se es profesor en la misma universidad donde se obtuvo la licenciatura. Sencillamente para evitar el... #URL# </document>
# 		<document> RT #USER#: 'Violencia de género' en 2019:
#
# - Aumenta el nº de mujeres asesinadas a la cifra más alta desde 2015 (la LIVG no funciona)
#
# -… </document>
#
# Not-Preprocessed samples:
#  tf.Tensor([b'<author lang="es">\n\t<documents>\n\t\t<document><![CDATA[#USER# #USER# Pero a\xc3\xban ni las fiestas Patrias han empezado.. no chinguen! \xf0\x9f\x98\x82\xf0\x9f\x98\x82]]></document>\n\t\t<document><![CDATA[#USER# M\xc3\xa1s bien falta que haga rosca de reyes versi\xc3\xb3n pan de muerto.. \xf0\x9f\x98\x82\xf0\x9f\x98\x82\xf0\x9f\x98\x82]]></document>\n\t\t<document><![CDATA[\xc2\xa1\xc2\xa1Buenos d\xc3\xadas Aparicios!!]]></document>\n\t\t<document><![CDATA[#USER# Con todo y su ramita de apio para el deTox .. \xf0\x9f\x98\x86\xf0\x9f\x98\x86]]></document>\n\t\t<document><![CDATA[#USER# Siempre contenta, siempre entusiasta!! \xf0\x9f\xa4\xa3\xf0\x9f\xa4\xa3\xf0\x9f\x98\x82\xf0\x9f\x98\x82]]></document>\n\t\t<document><![CDATA[#HASHTAG# #HASHTAG# en fin de semana con Lobosho.. \xf0\x9f\xa4\xa3\xf0\x9f\x90\xaf\xf0\x9f\x90\xba\xf0\x9f\x90\xbb #URL#]]></document>\n\t\t<document><![CDATA[#USER# A veces me da curiosidad de ir, nada m\xc3\xa1s para saber que dicen.. \xf0\x9f\xa4\xa3]]></document>\n\t\t<document><![CDATA[#USER# Pues ya vamos en el Mexib\xc3\xbas y pues una maravilla de transporte.. \xf0\x9f\x98\x83\xf0\x9f\x98\x83\xf0\x9f\x98\x83]]></document>\n\t\t<document><![CDATA[#USER# \xc2\xa1\xc2\xa1Asi se va a extinguir la humanidad Alberto!! \xf0\x9f\x98\x86\xf0\x9f\x98\x86]]></document>\n\t\t<document><![CDATA[#USER# Buenos d\xc3\xadas Chef! \xe2\x9c\x8c\xf0\x9f\x8d\x9d\xf0\x9f\x8d\x9c\xf0\x9f\x8d\xb2]]></document>\n\t\t<document><![CDATA[#USER# #USER# Ajajajaja yo nada m\xc3\xa1s dec\xc3\xada.. \xf0\x9f\xa4\xa3\xf0\x9f\xa4\xa3\xf0\x9f\xa4\xa3]]></document>\n\t\t<document><![CDATA[#USER# #USER# *A Gel Xiomara le gusta esta publicaci\xc3\xb3n.. \xf0\x9f\x98\x86\xf0\x9f\x98\x86]]></document>\n\t\t<document><![CDATA[#USER# #USER# Y qu\xc3\xa9 tal si lo m\xc3\xado un perro? \xf0\x9f\x90\x95\xf0\x9f\xa4\x94\xf0\x9f\xa4\x94]]></document>\n\t\t<document><![CDATA[El Museo Internacional del #HASHTAG# es visita obligada cu\xc3\xa1ndo vienes a #HASHTAG# #USER#  \xf0\x9f\x98\x8d\xf0\x9f\xa4\xa9 #URL#]]></document>\n\t\t<document><![CDATA[Definitivamente el norte de M\xc3\xa9xico es como si fuera otro pais.\n\nHablan otro idioma y la gente tiene otras costumbres.. \xf0\x9f\xa4\xa3\xf0\x9f\xa4\xa3]]></document>\n\t\t<document><![CDATA[#USER# #USER# H\xc3\xadjole.. como que no se.. a\xc3\xban no me convence..\xf0\x9f\xa4\x94\xf0\x9f\xa4\x94]]></document>\n\t\t<document><![CDATA[#USER# #USER# Eso me recuerda.. Nunca inviertas la polaridad de un capacitor. Puede ser una experiencia terrible.. \xf0\x9f\x98\x82\xf0\x9f\x98\x85\xf0\x9f\x92\xa3\xf0\x9f\x92\xa5]]></document>\n\t\t<document><![CDATA[Inviertanle tantito a sus fiestas y festivales de m\xc3\xbasica. \n\nSalir de su pa\xc3\xads les da otra perspectiva del mundo, aunque sea para enfiestar...]]></document>\n\t\t<document><![CDATA[Son las 15:45 y aun parece que son las 10 de la ma\xc3\xb1ana.. #HASHTAG#]]></document>\n\t\t<document><![CDATA[RT #USER#: El nombramiento de Manuel Espino como coordinador de organizaciones sociales/civiles de AMLO es un golpe a quienes han\xe2\x80\xa6]]></document>\n\t\t<document><![CDATA[\xc2\xa1\xc2\xa1Buenos y frescos d\xc3\xadas!! \xf0\x9f\x98\x83\xf0\x9f\x98\x83]]></document>\n\t\t<document><![CDATA[Queridos #HASHTAG# #HASHTAG# de Asturias \xf0\x9f\x8e\x88\xf0\x9f\x8e\x81\xf0\x9f\x8e\x86\xf0\x9f\x8e\x89\xf0\x9f\x98\x84\xf0\x9f\x98\x84 #URL#]]></document>\n\t\t<document><![CDATA[El vuelo est\xc3\xa1 hasta la Madre.. #HASHTAG# \xf0\x9f\x98\x82\xf0\x9f\x98\x82\xf0\x9f\x98\x82 #URL#]]></document>\n\t\t<document><![CDATA[RT #USER#: Me pongo de pie por todos los que desde su trinchera aportan su granito de arena para que la comunidad #HASHTAG# viva e\xe2\x80\xa6]]></document>\n\t\t<document><![CDATA[Se siente bien bonito cuando lo sue\xc3\xb1os se materializan.. aunque los hayas sacado a meses sin intereses..\xf0\x9f\x98\x82\xf0\x9f\x98\x82]]></document>\n\t\t<document><![CDATA[Literal estoy hasta el Nido de Quetzalc\xc3\xb3atl.. \xf0\x9f\x90\ ...
# Preprocessed samples:
#
# 	<document> #USER# #USER# Pero aún ni las fiestas Patrias han empezado.. no chinguen! 😂😂 </document>
# 		<document> #USER# Más bien falta que haga rosca de reyes versión pan de muerto.. 😂😂😂 </document>
# 		<document> ¡¡Buenos días Aparicios!! </document>
# 		<document> #USER# Con todo y su ramita de apio para el deTox .. 😆😆 </document>
# 		<document> #USER# Siempre contenta, siempre entusiasta!! 🤣🤣😂😂 </document>
# 		<document> #HASHTAG# #HASHTAG# en fin de semana con Lobosho.. 🤣🐯🐺🐻 #URL# </document>
# 		<document> #USER# A veces me da curiosidad de ir, nada más para saber que dicen.. 🤣 </document>
# 		<document> #USER# Pues ya vamos en el Mexibús y pues una maravilla de transporte.. 😃😃😃 </document>
# 		<document> #USER# ¡¡Asi se va a extinguir la humanidad Alberto!! 😆😆 </document>
# 		<document> #USER# Buenos días Chef! ✌🍝🍜🍲 </document>
# 		<document> #USER# #USER# Ajajajaja yo nada más decía.. 🤣🤣🤣 </document>
# 		<document> #USER# #USER# *A Gel Xiomara le gusta esta publicación.. 😆😆 </document>
# 		<document> #USER# #USER# Y qué tal si lo mío un perro? 🐕🤔🤔 </document>
# 		<document> El Museo Internacional del #HASHTAG# es visita obligada cuándo vienes a #HASHTAG# #USER#  😍🤩 #URL# </document>
# 		<document> Definitivamente el norte de México es como si fuera otro pais.
#
# Hablan otro idioma y la gente tiene otras costumbres.. 🤣🤣 </document>
# 		<document> #USER# #USER# Híjole.. como que no se.. aún no me convence..🤔🤔 </document>
# 		<document> #USER# #USER# Eso me recuerda.. Nunca inviertas la polaridad de un capacitor. Puede ser una experiencia terrible.. 😂😅💣💥 </document>
# 		<document> Inviertanle tantito a sus fiestas y festivales de música.
#
# Salir de su país les da otra perspectiva del mundo, aunque sea para enfiestar... </document>
# 		<document> Son las 15:45 y aun parece que son las 10 de la mañana.. #HASHTAG# </document>
# 		<document> RT #USER#: El nombramiento de Manuel Espino como coordinador de organizaciones sociales/civiles de AMLO es un golpe a quienes han… </document>
# 		<document> ¡¡Buenos y frescos días!! 😃😃 </document>
# 		<document> Queridos #HASHTAG# #HASHTAG# de Asturias 🎈🎁🎆🎉😄😄 #URL# </document>
# 		<document> El vuelo está hasta la Madre.. #HASHTAG# 😂😂😂 #URL# </document>
# 		<document> RT #USER#: Me pongo de pie por todos los que desde su trinchera aportan su granito de arena para que la comunidad #HASHTAG# viva e… </document>
# 		<document> Se siente bien bonito cuando lo sueños se materializan.. aunque los hayas sacado a meses sin intereses..😂😂 </document>
# 		<document> Literal estoy hasta el Nido de Quetzalcóatl.. 🐍🌵🌵 </document>
# 		<document> Le voy a marcar hasta que la pinche bateria del celular se le acabe..😡😡 </document>
# 		<document> #USER# Te vas a pegar unos Mamelucos.. 😂😂😂😂 #HASHTAG# </document>
# 		<document> #USER# Hijo le no soy de IPhone mi Charlie. . Yo puro Motorola. .😃😃 </document>
# 		<document> Encabronado y lo que le sigue.. 😠😠😠 </document>
# 		<document> Los domingos también nos reunimos.. #HASHTAG# 🍻🍻 #URL# </document>
# 		<document> #USER# Pos oye!! El alimento para las hijas es básico.. 😆😆 </document>
# 		<document> #USER# Pero a mí sí los DMs... 😆😆🤣🤣🤣🤣 </document>
# 		<document> ¡¡Buenos, fríos y nublados días!!
#
# ☁☁🌥☁☁☁ </document>
# 		<document> #USER# #USER# #USER# #USER# #USER# #USER# #USER# #USER# No salió mal la numeración?? 🤔🤔🤔 </document>
# 		<document> #USER# #USER# #USER# #USER# Por eso nos vamos hoy para llegar el 19 ..😂😂😂 </document>
# 		<document> #USER# Ajajaja duda uno cuál taco de canasta recién hecho amigo.. 🤣🤣🤣 </document>
# 		<document> #USER# Buenos!! 😄😄 </document>
# 		<document> #USER# #USER# El edificio de xola que se dañó en el sismo pasado sigue en pie pero cayeron un poco de escombros.. </document>
# 		<document> Buenos días! (@ Mastercard in Mexico City, DF w/ #USER#) #URL# </document>
# 		<document> #USER# ajajajaja lo malo es que ni un pedacito me compartieron..
# 😆😆 </document>
# 		<document> #USER# #USER# O ya de plano unas bonitas cartulinas 😂😂 </document>
# 		<document> ¡¡Buenos días!! A todos aquellos que vienen del Metro L2. Las Américas, Xola, Alamos y C. SCOP Siguen sin servicio en el metrobus L2. #URL# </document>
# 		<document> Ya que andamos en el #HASHTAG# #HASHTAG# al menos conocer un poco más de los símbolos que nos identifican
#
# #URL# </document>
# 		<document> ¡¡Buenos días #HASHTAG# !! Ya mañana es #HASHTAG# #HASHTAG# ¿Que le van a pedir a Juan Gabriel? 😆😆 </document>
# 		<document> #USER# 😱🐉😂😂... Le íntegras el C-Ring 🤣🤣 </document>
# 		<document> #USER# Obvio yo soy el gatito patitas blancas.. 🤣🤣🤣 </document>
# 		<document> #USER# Yo mañana pongo en la jugada al Captain Morgan.. con todo y su twist de limón..😂😂 </document>
# 		<document> #USER# #USER# #USER# Super recomendable el lugar! 😄😄 </document>
# 		<document> #URL#
#
# Pues a mi si le gustó el video de la Katy Perry Prime.. aunque ya vimos cual será el disfraz para Halloween 🐯🐯 </document>
# 		<document> Oigan Parceros su país está bien bonito.. 🇨🇴🇨🇴🇨🇴 #HASHTAG# </document>
# 		<document> Estoy a dos de aplicar la de "Te lo dije" a uno de mis coworkers </document>
# 		<document> #USER# Y a la comadre mucho más!! 🤣🤣🤣 </document>
# 		<document> #USER# jajajaja siento que es como la de "El Burrito Sabanero" ajajajaja 😂😂 </document>
# 		<document> Si la andas cague, cague y cague, llega un momento en que se acaba el papel de baño.. </document>
# 		<document> #USER# Y uno aquí aún sin desayunar porque Don #USER# sigue dormido.. 😥😥 </document>
# 		<document> #USER# 🤣🤣🤣 Directo al Oscar como mejor actor de reparto.. 🤣🤣 </document>
# 		<document> Ese Rafita Márquez si se tomó muy en serio ser el "Crack" de la Selección.. 😹😹 </document>
# 		<document> #USER# #USER# No te preocupes, llegando las conecto.. 🤣🤣🤣🤣🤣🤣 </document>
# 		<document> #USER# #USER# La próxima es en Miami!! 😋😃😃🌴🌴 </document>
# 		<document> #USER# #USER# Muchas gracias Isaac!! 😄😄😄 </document>
# 		<document> #USER# Con 8hrs de sueño reglamentarias! 👏👏😂😂 </document>
# 		<document> Regla Godin #HASHTAG# : Nunca de los nuncas guardes un tupper limpio con la tapa puesta.. ☝️ </document>
# 		<document> #USER# Ese fue el problema.. demasiada carga y la batería valió madres..😬😬 </document>
# 		<document> #USER# No se aprobó? 🙀🙀 </document>
# 		<document> Motivación: La decisión de realizar un esfuerzo para lograr un objetivo. </document>
# 		<document> RT #USER#: Lo bueno de las redes sociales es que le dan voz a la opinión de cualquier persona, lo malo de las redes sociales es que le d… </document>
# 		<document> #USER# #USER# Ora! que yo no fui.. fue la vecina.. 😂😂 </document>
# 		<document> RT #USER#: El orgullo gay no nació de la necesidad de celebrar el hecho de ser gay, sino de nuestro derecho a existir libres de pers… </document>
# 		<document> ¡¡ Ya que alguien saque la imagen de "Que tipo de Pan de Dulce eres de acuerdo a tu signo zodiacal" !! 😆😂 </document>
# 		<document> #USER# He ahí el problema de una mala planeación, terminas mal baratando un evento que pudo haber sido bueno.. #HASHTAG# </document>
# 		<document> #USER# Que de plano solo se la viven aquí.. 🤫🤷 </document>
# 		<document> #USER# Acá la cuidamos.. ¿A donde te vas? </document>
# 		<document> #USER# Ajajaja te quedan sólo 3 semanas según el calendario no oficial festivo 😂 </document>
# 		<document> ¡¡Buenos días Raza!! 🤣🤣 </document>
# 		<document> #USER# 🤣🤣🤣🤣🤣 pero así le hago a Nala y a Khora.. por qué a ti te infló otros cachetes.. 🤣🤣🤣😍😍 #HASHTAG# </document>
# 		<document> ¡¡Buenos y calurosos días!! Ya empieza a subir la temperatura en la #HASHTAG# 😃😃 </document>
# 		<document> Nunca falta en estos cursos el 1+ 😒😒 </document>
# 		<document> #USER# #USER# Wooeeeyyy el pan de muerto es una adicción!! 😂😂 </document>
# 		<document> #USER# Si por favor.. Gracias! </document>
# 		<document> #USER# Ya ni los muertos repetas.. 🤣🤣🤣 </document>
# 		<document> RT #USER#: Que bonito se siente cuando el cliente te felicita por tu trabajo.
#
# 😍😍😍😍😍😍😍 </document>
# 		<document> #USER# 🤣🤣🤣 el Abanico LGBT+ 🏳️‍🌈🏳️‍🌈 </document>
# 		<document> #USER# #USER# #USER# Nosotros en niños bien del CUM.. jajajajaja </document>
# 		<document> RT #USER#: No importa el destino del viaje, lo importante es recorrer el camino con la persona que amas. Te amo #USER#
# 😍😍😍👬👬… </document>
# 		<document> ¡¡Buenas tardes chavas!!
#
# *Me vale madres!.. en horario del ESTE ya son las 12... </document>
# 		<document> #USER# #URL#
#
# GM esta la 3ra posicion del ranking de Super Empresas y ocupa el 1er puesto en el sector Automotriz. #URL# </document>
# 		<document> ¡¡Buenos días Chakales del mundo!! </document>
# 		<document> #USER# #USER# Ánimo! ! Te mandamos porras y que quede muy bien! </document>
# 		<document> No mamen el final de "Another Life" me urge que salga la segunda temporada.. 😬😬👽👽🤖🤖 </document>
# 		<document> #USER# Muy buenos.. 😃😃 </document>
# 		<document> #USER# Hasta las 8 pero ya hay que irse levantado . 😆 </document>
# 		<document> #USER# Ya llegamos.. en intensas! 😜😜 </document>
# 		<document> Queridos hermanos podemos ir en paz..
#
# Nuestra junta de RH ha terminado...
#
# demos gracias al señor director.. </document>
# 		<document> #USER# No pues no.. ya ves.. 280 caracteres y no te sabes expresar bien ajajajajaja 😂😂😂😂 </document>
# 		<document> #USER# Según leo de varios creo literal los han timado con esa serie.. 😂😂 </document>
# 		<document> Hoy si fui, ingeniero, licenciado, comunicologo, mercadólogo, diseñador gráfico, madre y padre a la vez.. </document>
# 		<document> ¿Oye Nala? Ya vamos de regreso, pasas por nosotros al aeropuerto 😁😁 Cc #USER# #URL# </document>
# 		<document> Poderes de las Chachas fantásticas.. ¡Activense! 👯
#
# ¡¡Y pum!!  ¡¡la casa quedó super limpia!! 🏠 </document>
# 		<document> ¡¡Buenos días San Luis Potosí!! 😄😄😄 </document>

# %% [markdown]
# ## Model definition.

# %%
# check gpu
cuda_available = torch.cuda.is_available()

print('Cuda available? ',cuda_available)

# English Model Training. 
#4 Max epochs of training as in 'BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding'.
model_en_args = ClassificationArgs(num_train_epochs=4, 
                                      no_save=True, 
                                      no_cache=True, 
                                      overwrite_output_dir=True)
model_en = ClassificationModel("bert", 
                                  'bert-base-cased', 
                                  args = model_en_args, 
                                  num_labels=2, 
                                  use_cuda=cuda_available)
# train model
model_en.train_model(train_df_en[['text', 'label']])

# Spanish Model Training.
#4 Max epochs of training as in 'BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding'.
model_es_args = ClassificationArgs(num_train_epochs=4, 
                                      no_save=True, 
                                      no_cache=True, 
                                      overwrite_output_dir=True)
model_es = ClassificationModel("bert", 
                                  'bert-base-cased', 
                                  args = model_es_args, 
                                  num_labels=2, 
                                  use_cuda=cuda_available)
# train model
model_es.train_model(train_df_es[['text', 'label']])
# Out:
# Cuda available?  True
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/38 [00:00<?, ?it/s]
# Running Epoch 1 of 4:   0%|          | 0/38 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/38 [00:00<?, ?it/s]
# Running Epoch 3 of 4:   0%|          | 0/38 [00:00<?, ?it/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Running Epoch 0 of 4:   0%|          | 0/38 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Running Epoch 1 of 4:   0%|          | 0/38 [00:00<?, ?it/s]
# Running Epoch 2 of 4:   0%|          | 0/38 [00:00<?, ?it/s]
# Running Epoch 3 of 4:   0%|          | 0/38 [00:00<?, ?it/s]
# (152, 0.5595563587389494)

# %% [markdown]
# ## Evaluate the model on test set

# %%
result_en, model_outputs_en, wrong_predictions_en = model_en.eval_model(test_df_en)

result_es, model_outputs_es, wrong_predictions_es = model_es.eval_model(test_df_es)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/200 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/25 [00:00<?, ?it/s]

# %% [markdown]
# ## Print results

# %%
# Results on english dataset.
print(result_en)
correct_predictions = result_en['tp']+result_en['tn']
print(correct_predictions)
total_predictions = result_en['tp']+result_en['tn']+result_en['fp']+result_en['fn']
print(total_predictions)
accuracy = correct_predictions/total_predictions
print("Accuracy on English test set is:",accuracy)

# Results on spanish dataset.
print(result_es)
correct_predictions = result_es['tp']+result_es['tn']
print(correct_predictions)
total_predictions = result_es['tp']+result_es['tn']+result_es['fp']+result_es['fn']
print(total_predictions)
accuracy = correct_predictions/total_predictions
print("Accuracy on Spanish test set is:",accuracy)
# Out:
# {'mcc': 0.1805787796286538, 'tp': 55, 'tn': 63, 'fp': 37, 'fn': 45, 'auroc': 0.61605, 'auprc': 0.5906878487956888, 'eval_loss': 0.9506918334960938}
# 118
# 200
# Accuracy on English test set is: 0.59
# {'mcc': 0.33909081143141073, 'tp': 55, 'tn': 78, 'fp': 22, 'fn': 45, 'auroc': 0.7164999999999999, 'auprc': 0.721174730530863, 'eval_loss': 0.6670379638671875}
# 133
# 200
# Accuracy on Spanish test set is: 0.665
